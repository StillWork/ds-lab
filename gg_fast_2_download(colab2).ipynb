# %% [markdown]
# <a href="https://colab.research.google.com/github/StillWork/ds-lab/blob/master/gg_fast_2_download(colab2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 구글 이미지 다운받기
#
# ### 런타임 확인 !!
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*
#
# 자신의 PC에서 구글 이미지를 스크롤한 후 이를 다운 받을 수 있다. 구글은 700장의 사진까지 다운받을 수 있다.
#
# 스크롤한 이미지의 URL을 저장하는 자바스크립트를 수행한다. 아래와 같은 명령으로 창을 만든다.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac
#
#
# 아래 스크립트를 실행한다.
#
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### 이미지를 다운로드할 폴더를 만들고 위에서 만든 url 파일을 업로드한다.

# %%
from fastai import *
from fastai.vision import *

# %%
# !mkdir bears
# Out:
# mkdir: cannot create directory ‘bears’: File exists

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-69c359cc-6179-4571-aef1-2c2322135435" name="files[]" multiple disabled />
#      <output id="result-69c359cc-6179-4571-aef1-2c2322135435">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving teddys.csv to teddys (1).csv
# {'teddys.csv': b'https://www.buildabear.com/dw/image/v2/BBNG_PRD/on/demandware.static/-/Sites-buildabear-master/default/dwa4ae30da/25239x.jpg?sw=600&sh=600&sm=fit\nhttps://images-na.ssl-images-amazon.com/images/I/41nGGVyAxJL._SX425_.jpg\nhttps://www.buildabear.com/dw/image/v2/BBNG_PRD/on/demandware.static/-/Sites-buildabear-master/default/dwdc7fb032/25720x.jpg?sw=600&sh=600&sm=fit\nhttps://cdn.shopify.com/s/files/1/1920/7987/products/Bear_in_Robe_1000x1000.jpg?v=1509394168\nhttp://cdn.shopify.com/s/files/1/0084/9282/products/Harvard-Bear-_Caramel_-min_1024x1024.jpg?v=1500302166\nhttps://rukminim1.flixcart.com/image/832/832/jduk2vk0/stuffed-toy/k/6/3/5-feet-cream-color-teddy-bear-152-cm-beige-152-stj-soft-toys-original-imaexv5y7cfhymkk.jpeg?q=70\nhttps://images-na.ssl-images-amazon.com/images/I/71f-PFbeSRL._SX425_.jpg\nhttps://douglascuddletoy.com/wp-content/uploads/2016/06/12704.jpg\nhttps://images-na.ssl-images-amazon.com/images/I/61u0xWR5HnL._SX466_.jpg\nhttps://5.imimg.com/data5/UI/DJ/MY-45822456/teddy-bear-500x500.jpg\nhttps://cloudinary-a.akamaihd.net/ufn/image/upload/1517501957170_3.jpg\nhttps://rukminim1.flixcart.com/image/704/704/j69mz680/stuffed-toy/p/w/h/stuffed-spongy-huggable-cute-rose-teddy-bear-pink-color-60-avs-original-imaewqxzbyapg4x9.jpeg?q=70\nhttps://upload.wikimedia.org/wikipedia/commons/d/d8/Teddy_bear_early_1900s_-_Smithsonian_Museum_of_Natural_History.jpg\nhttp://cdn.fcglcdn.com/brainbees/images/products/438x531/1301400a.jpg\nhttps://www.visitglendale.com/wp-content/uploads/2018/06/teddy-bear-day4.png\nhttps://i5.walmartimages.com/asr/7617e51c-6004-42c1-ae63-006728db4ced_1.e3d0bbf4faa40c0a21af34e4f1d02546.jpeg?odnHeight=450&odnWidth=450&odnBg=FFFFF
_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:12<00:00]
#     </div>
# Error https://www.sendah.com/988-thickbox_default/daydream-white-teddy-bear.jpg HTTPSConnectionPool(host='www.sendah.com', port=443): Max retries exceeded with url: /988-thickbox_default/daydream-white-teddy-bear.jpg (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:847)'),))
# Error https://www.hofbraeuhaus-shop.de/out/pictures/master/product/1/freigestellterbr.jpg HTTPSConnectionPool(host='www.hofbraeuhaus-shop.de', port=443): Max retries exceeded with url: /out/pictures/master/product/1/freigestellterbr.jpg (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:847)'),))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:11<00:00]
#     </div>
# Error https://animalfactguide.com/wp-content/uploads/2013/01/grizzlybear-2.jpg HTTPSConnectionPool(host='animalfactguide.com', port=443): Max retries exceeded with url: /wp-content/uploads/2013/01/grizzlybear-2.jpg (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:847)'),))
# Error https://www.washingtonpost.com/pbox.php?url=http://www.washingtonpost.com/news/animalia/wp-content/uploads/sites/56/2016/06/cub1.jpg&w=1484&op=resize&opt=1&filter=antialias&t=20170517 HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error https://www.washingtonpost.com/resizer/3XR_4pCQML_c_PWsg5ByKcFsJow=/1484x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/AUEKO7HTGII6RGOCZ7FG7T3BBQ.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:13<00:00]
#     </div>
# Error https://caldwellzoo.org/wp-content/uploads/2017/04/NORTH-AMERICAN-BLACK-BEAR.jpg HTTPSConnectionPool(host='caldwellzoo.org', port=443): Max retries exceeded with url: /wp-content/uploads/2017/04/NORTH-AMERICAN-BLACK-BEAR.jpg (Caused by SSLError(SSLError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed (_ssl.c:847)'),))
# Error https://www.washingtonpost.com/resizer/vn6pmHdQPxRzwhhFkpSEsmUp9Qc=/534x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/XK6YBT5GSE2LROLN3FO4WRK5JI.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error https://bear-ology.org/images/LargestBlackBears-1.jpg HTTPSConnectionPool(host='bear-ology.org', port=443): Read timed out. (read timeout=4)

# %% [markdown]
# ## 이미지를 다운로드 하고 확인한다.

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# teddys
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='196' class='' max='196', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [196/196 00:04<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='bears/teddys/00000090.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/teddys/00000007.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/teddys/00000084.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/teddys/00000122.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/teddys/00000039.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/teddys/00000164.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/teddys/00000133.jpeg'>
# grizzly
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='194' class='' max='194', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [194/194 00:06<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='bears/grizzly/00000160.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/grizzly/00000146.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/grizzly/00000104.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/grizzly/00000149.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/grizzly/00000179.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/grizzly/00000157.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/grizzly/00000192.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/grizzly/00000141.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/grizzly/00000193.jpg'>
# black
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='197' class='' max='197', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [197/197 00:06<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='bears/black/00000174.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/black/00000014.png'>
# cannot identify image file <_io.BufferedReader name='bears/black/00000007.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/black/00000042.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/black/00000019.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/black/00000195.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/black/00000197.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/black/00000189.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/black/00000119.jpg'>
# cannot identify image file <_io.BufferedReader name='bears/black/00000063.png'>
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:925: UserWarning: Couldn't allocate palette entry for transparency
#   "for transparency")
# int() argument must be a string, a bytes-like object or a number, not 'tuple'

# %% [markdown]
# ## 이미지 확인

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['black', 'grizzly', 'teddys']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['black', 'grizzly', 'teddys'], 3, 448, 112)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.torch/models/resnet34-333f7ec4.pth
# 87306240it [00:01, 56467351.59it/s]

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 02:21 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.834033</td>
#       <td>0.173847</td>
#       <td>0.080357</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.452005</td>
#       <td>0.146406</td>
#       <td>0.053571</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.325544</td>
#       <td>0.165363</td>
#       <td>0.053571</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.244758</td>
#       <td>0.168553</td>
#       <td>0.053571</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='15', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       13.33% [2/15 00:57<06:16]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.047561</td>
#       <td></td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.053576</td>
#       <td></td>
#       <td>00:29</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='7', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/7 00:00<00:00]
#     </div>

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-4))
# Out:
# Total time: 01:13 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.080482</td>
#       <td>0.169310</td>
#       <td>0.053571</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.067219</td>
#       <td>0.175325</td>
#       <td>0.053571</td>
#       <td>00:37</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(2)
