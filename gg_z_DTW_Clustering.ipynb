# %% [markdown]
# <a href="https://colab.research.google.com/github/StillWork/ds-lab/blob/master/gg_z_DTW_Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Time Series Classification and Clustering

# %% [markdown]
# In a typical classification problem you are given a set of input features and a set of discrete output classes and you want to model the relationship between the two.  There is a myriad of classification algorithms that you could use for this problem - SVMs, Naive Bayes, k-NN, etc.  But what if the input features are not independent such as with time series data?  In this case SVMs and Naive Bayes would not be a good choice since they assume that the input features are independent.  The k-NN algorithm could still work however it relies on the notion of a similarity measure between input examples.  Now the question becomes _how do we measure the similarity between two time series_?

# %% [markdown]
# ##How about Euclidean distance?

# %% [markdown]
# The Euclidean distance between two time series $Q$ and $C$ of length $n$ is defined as
#
# $$d(Q,C) = \sqrt{\sum^n_{i=1}[Q(i)-C(i)]^2}$$
#
# At first glance, it seems like simply calculating the Euclidean distance between two time series would give us a good idea of the similarity between them.  After all, the Euclidean distance between identical time series is zero and the Euclidean distance between very different time series is large.  However, before we settle on Euclidean distance as a similarity measure we should clearly state our desired criteria for determining the similarity between two time series

# %% [markdown]
# With a good similarity measure, small changes in two time series should result in small changes in their similarity.  With respect to Euclidean distance this is true for changes in the y-axis, but it is not true for changes in the time axis (i.e. compression and stretching).  Consider the following example.

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
from math import sqrt

x=np.linspace(0,50,100)
ts1=pd.Series(3.1*np.sin(x/1.5)+3.5)
ts2=pd.Series(2.2*np.sin(x/3.5+2.4)+3.2)
ts3=pd.Series(0.04*x+3.0)

ts1.plot()
ts2.plot()
ts3.plot()

plt.ylim(-2,10)
plt.legend(['ts1','ts2','ts3'])
plt.show()

# %% [markdown]
# In the above example, it is clear that $ts1$ and $ts2$ are most similar (they are both $sin$ functions under different transformations).  $ts3$ is clearly the most different. Let's compute the Euclidean distance $d(ts1,ts2)$ and $d(ts1,ts3)$ to see if the Euclidean distance measure agrees with what our intuition tells us.  Let's first create a function that computes the Euclidean distance between two time series.

# %%
def euclid_dist(t1,t2):
    return sqrt(sum((t1-t2)**2))

# %% [markdown]
# Let's now find the Euclidean distance between $ts1$ and $ts2$

# %%
print euclid_dist(ts1,ts2)
# Out:
# 26.959216038

# %% [markdown]
# and the Euclidean distance between $ts1$ and $ts3$

# %%
print euclid_dist(ts1,ts3)
# Out:
# 23.1892491903

# %% [markdown]
# This is not good because according to the Euclidean distance measure, $ts1$ is more similar to $ts3$ than to $ts2$ which contradicts our intuition.  This is the problem with using the Euclidean distance measure.  It often produced pessimistic similarity measures when it encounters distortion in the time axis.  The way to deal with this is to use dynamic time warping.

# %% [markdown]
# ##Dynamic Time Warping

# %% [markdown]
# Dynamic time warping finds the optimal non-linear alignment between two time series.  The Euclidean distances between alignments are then much less susceptable to pessimistic similarity measurements due to distortion in the time axis.  There is a price to pay for this, however, because dynamic time warping is quadratic in the length of the time series used.

# %% [markdown]
# Dynamic time warping works in the following way. Consider two time series $Q$ and $C$ of the same length $n$ where $$Q=q_1,q_2,...,q_n$$ and $$C=c_1,c_2,...,c_n$$ The first thing we do is construct an $n\times n$ matrix whose $i,j^{th}$ element is the Euclidean distance between $q_i$ and $c_j$.  We want to find a path through this matrix that minimizes the cumulative distance.  This path then determines the optimal alignment between the two time series.  It should be noted that it is possible for one point in a time series to be mapped to multiple points in the other time series.

# %% [markdown]
# Let's call the path $W$ where $$W=w_1,w_2,...,w_K$$ where each element of $W$ represents the distance between a point $i$ in $Q$ and a point $j$ in $C$ i.e. $w_k=(q_i-c_j)^2$

# %% [markdown]
# So we want to find the path with the minimum Euclidean distance $$W^*=argmin_W(\sqrt{\sum_{k=1}^Kw_k})$$ The optimal path is found via dynamic programming, specifically the following recursive function. $$\gamma(i,j)=d(q_i,c_j)+min ( \gamma(i-1,j-1),\gamma(i-1,j),\gamma(i,j-1))$$

# %%
def DTWDistance(s1, s2):
    DTW={}
    
    for i in range(len(s1)):
        DTW[(i, -1)] = float('inf')
    for i in range(len(s2)):
        DTW[(-1, i)] = float('inf')
    DTW[(-1, -1)] = 0

    for i in range(len(s1)):
        for j in range(len(s2)):
            dist= (s1[i]-s2[j])**2
            DTW[(i, j)] = dist + min(DTW[(i-1, j)],DTW[(i, j-1)], DTW[(i-1, j-1)])
		
    return sqrt(DTW[len(s1)-1, len(s2)-1])

# %% [markdown]
# Now let's compute the Euclidean distance between $ts1$ and $ts2$ using dynamic time warping.

# %%
print DTWDistance(ts1,ts2)
# Out:
# 17.9297184686

# %% [markdown]
# and now the dynamic time warping distance between $ts1$ and $ts3$

# %%
print DTWDistance(ts1,ts3)
# Out:
# 21.5494948244

# %% [markdown]
# As you can see, our results have changed from when we only used the Euclidean distance measure.  Now, in agreement with our intuition, $ts2$ is shown to be more similar to $ts1$ than $ts3$ is.

# %% [markdown]
# ###Speeding Up Dynamic Time Warping

# %% [markdown]
# Dynamic time warping has a complexity of $O(nm)$ where $n$ is the length of the first time series and $m$ is the length of the second time series.  If you are performing dynamic time warping multiple times on long time series data, this can be prohibitively expensive.  However, there are a couple of ways to speed things up.  The first is to enforce a locality constraint.  This works under the assumption that it is unlikely for $q_i$ and $c_j$ to be matched if $i$ and $j$ are too far apart.  The threshold is determined by a window size $w$.  This way, only mappings within this window are considered which speeds up the inner loop. The following is the modified code which includes the window size $w$.

# %%
def DTWDistance(s1, s2,w):
    DTW={}
    
    w = max(w, abs(len(s1)-len(s2)))
    
    for i in range(-1,len(s1)):
        for j in range(-1,len(s2)):
            DTW[(i, j)] = float('inf')
    DTW[(-1, -1)] = 0
  
    for i in range(len(s1)):
        for j in range(max(0, i-w), min(len(s2), i+w)):
            dist= (s1[i]-s2[j])**2
            DTW[(i, j)] = dist + min(DTW[(i-1, j)],DTW[(i, j-1)], DTW[(i-1, j-1)])
		
    return sqrt(DTW[len(s1)-1, len(s2)-1])

# %% [markdown]
# Let's test this faster version.

# %%
print DTWDistance(ts1,ts2,10)
# Out:
# 18.5965518384

# %%
print DTWDistance(ts1,ts3,10)
# Out:
# 22.4724828468

# %% [markdown]
# Another way to speed things up is to use the _LB Keogh_ lower bound of dynamic time warping.  It is defined as $$LBKeogh(Q,C)=\sum_{i=1}^n (c_i-U_i)^2I(c_i > U_i)+(c_i-L_i)^2I(c_i < L_i)$$
# where $U_i$ and $L_i$ are upper and lower bounds for time series $Q$ which are defined as $U_i=max(q_{i-r}:q_{i+r})$ and $L_i=min(q_{i-r}:q_{i+r})$ for a reach $r$ and $I(\cdot)$ is the indicator function. It can be implemented with the following function.

# %%
def LB_Keogh(s1,s2,r):
    LB_sum=0
    for ind,i in enumerate(s1):
        
        lower_bound=min(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        upper_bound=max(s2[(ind-r if ind-r>=0 else 0):(ind+r)])
        
        if i>upper_bound:
            LB_sum=LB_sum+(i-upper_bound)**2
        elif i<lower_bound:
            LB_sum=LB_sum+(i-lower_bound)**2
    
    return sqrt(LB_sum)

# %% [markdown]
# Let's now test on $ts1$ and $ts2$

# %%
print LB_Keogh(ts1,ts2,20)
# Out:
# 6.25389235159

# %% [markdown]
# and now $ts1$ and $ts3$.

# %%
print LB_Keogh(ts1,ts3,20)
# Out:
# 19.9595478694

# %% [markdown]
# The _LB Keogh_ lower bound method is linear whereas dynamic time warping is quadratic in complexity which make it very advantageous for searching over large sets of time series.

# %% [markdown]
# ##Classification and Clustering

# %% [markdown]
# Now that we have a reliable method to determine the similarity between two time series, we can use the k-NN algorithm for classification.  Empirically, the best results have come when $k=1$.  The following is the 1-NN algorithm that uses dynamic time warping Euclidean distance.  In this algorithm, $train$ is the training set of time series examples where the class that the time series belongs to is appended to the end of the time series.  $test$ is the test set whose corresponding classes you are trying to predict.  In this algorithm, for every time series in the test set, a search must be performed through all points in the training set so that the most similar point is found.  Given that dynamic time warping is quadratic, this can be very computationally expensive.  We can speed up classification using the _LB Keogh_ lower bound.  Computing _LB Keogh_ is much less expensive than performing dynamic time warping.  And since $LB Keogh(Q,C) \leq DTW(Q,C)$ , we can eliminate time series that cannot possibly be more similar that the current most similar time series. In this way we are eliminating many unnecessary dynamic time warping computations.

# %%
from sklearn.metrics import classification_report

def knn(train,test,w):
    preds=[]
    for ind,i in enumerate(test):
        min_dist=float('inf')
        closest_seq=[]
        #print ind
        for j in train:
            if LB_Keogh(i[:-1],j[:-1],5)<min_dist:
                dist=DTWDistance(i[:-1],j[:-1],w)
                if dist<min_dist:
                    min_dist=dist
                    closest_seq=j
        preds.append(closest_seq[-1])
    return classification_report(test[:,-1],preds)

# %% [markdown]
# Now let's test it on some data. We will use a window size of 4.  Although the code is sped up with the use of the _LB Keogh_ bound and the dynamic time warping locality contraint, it may still take a few minutes to run.

# %%
# !wget https://github.com/alexminnaar/time-series-classification-and-clustering/blob/master/datasets/test.csv\
  -O test.csv
# Out:
# --2019-03-21 23:12:24--  https://github.com/alexminnaar/time-series-classification-and-clustering/blob/master/datasets/test.csv
# Resolving github.com (github.com)... 192.30.255.112, 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘test.csv’
#
# test.csv                [ <=>                ] 304.43K  --.-KB/s    in 0.06s
#
# 2019-03-21 23:12:25 (4.72 MB/s) - ‘test.csv’ saved [311740]

# %%
# !wget https://github.com/alexminnaar/time-series-classification-and-clustering/blob/master/datasets/train.csv\
  -O train.csv
# Out:
# --2019-03-21 23:11:46--  https://github.com/alexminnaar/time-series-classification-and-clustering/blob/master/datasets/train.csv
# Resolving github.com (github.com)... 192.30.253.113, 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘train.csv’
#
# train.csv               [  <=>               ] 304.43K  1.19MB/s    in 0.3s
#
# 2019-03-21 23:11:47 (1.19 MB/s) - ‘train.csv’ saved [311735]

# %%
train = np.genfromtxt('train.csv', delimiter='\t')
test = np.genfromtxt('test.csv', delimiter='\t')
print knn(train,test,4)
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-28-c4573e51474b> in <module>()
# ----> 1 train = np.genfromtxt('train.csv')
#       2 test = np.genfromtxt('test.csv')
#       3 print knn(train,test,4)
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2017             # Raise an exception ?
#    2018             if invalid_raise:
# -> 2019                 raise ValueError(errmsg)
#    2020             # Issue a warning ?
#    2021             else:
#
# ValueError: Some errors were detected !
#     Line #3 (got 1 columns instead of 2)
#     Line #5 (got 3 columns instead of 2)
#     Line #6 (got 3 columns instead of 2)
#     Line #7 (got 3 columns instead of 2)
#     Line #8 (got 3 columns instead of 2)
#     Line #9 (got 3 columns instead of 2)
#     Line #10 (got 3 columns instead of 2)
#     Line #11 (got 3 columns instead of 2)
#     Line #15 (got 7 columns instead of 2)
#     Line #16 (got 7 columns instead of 2)
#     Line #17 (got 7 columns instead of 2)
#     Line #23 (got 3 columns instead of 2)
#     Line #25 (got 7 columns instead of 2)
#     Line #26 (got 27 columns instead of 2)
#     Line #27 (got 5 columns instead of 2)
#     Line #28 (got 4 columns instead of 2)
#     Line #29 (got 3 columns instead of 2)
#     Line #32 (got 43 columns instead of 2)
#     Line #34 (got 3 columns instead of 2)
#     Line #36 (got 3 columns instead of 2)
#     Line #38 (got 4 columns instead of 2)
#     Line #43 (got 4 columns instead of 2)
#     Line #45 (got 3 columns instead of 2)
#     Line #46 (got 3 columns instead of 2)
#     Line #47 (got 3 columns instead of 2)
#     Line #49 (got 19 columns instead of 2)
#     Line #50 (got 5 columns instead of 2)
#     Line #54 (got 3 columns instead of 2)
#     Line #57 (got 5 columns instead of 2)
#     Line #63 (got 3 columns instead of 2)
#     Line #64 (got 3 columns instead of 2)
#     Line #66 (got 3 columns instead of 2)
#     Line #67 (got 3 columns instead of 2)
#     Line #69 (got 3 columns instead of 2)
#     Line #71 (got 3 columns instead of 2)
#     Line #73 (got 3 columns instead of 2)
#     Line #76 (got 8 columns instead of 2)
#     Line #78 (got 5 columns instead of 2)
#     Line #80 (got 28 columns instead of 2)
#     Line #83 (got 4 columns instead of 2)
#     Line #86 (got 3 columns instead of 2)
#     Line #88 (got 3 columns instead of 2)
#     Line #90 (got 4 columns instead of 2)
#     Line #91 (got 5 columns instead of 2)
#     Line #93 (got 3 columns instead of 2)
#     Line #98 (got 4 columns instead of 2)
#     Line #100 (got 1 columns instead of 2)
#     Line #102 (got 4 columns instead of 2)
#     Line #105 (got 4 columns instead of 2)
#     Line #107 (got 4 columns instead of 2)
#     Line #115 (got 7 columns instead of 2)
#     Line #116 (got 4 columns instead of 2)
#     Line #117 (got 4 columns instead of 2)
#     Line #118 (got 11 columns instead of 2)
#     Line #119 (got 67 columns instead of 2)
#     Line #120 (got 1 columns instead of 2)
#     Line #121 (got 1 columns instead of 2)
#     Line #123 (got 7 columns instead of 2)
#     Line #125 (got 7 columns instead of 2)
#     Line #126 (got 26 columns instead of 2)
#     Line #127 (got 1 columns instead of 2)
#     Line #128 (got 1 columns instead of 2)
#     Line #130 (got 3 columns instead of 2)
#     Line #131 (got 3 columns instead of 2)
#     Line #132 (got 11 columns instead of 2)
#     Line #133 (got 5 columns instead of 2)
#     Line #134 (got 8 columns instead of 2)
#     Line #136 (got 11 columns instead of 2)
#     Line #138 (got 1 columns instead of 2)
#     Line #139 (got 1 columns instead of 2)
#     Line #140 (got 10 columns instead of 2)
#     Line #141 (got 20 columns instead of 2)
#     Line #142 (got 4 columns instead of 2)
#     Line #143 (got 17 columns instead of 2)
#     Line #144 (got 17 columns instead of 2)
#     Line #145 (got 15 columns instead of 2)
#     Line #146 (got 15 columns instead of 2)
#     Line #147 (got 3 columns instead of 2)
#     Line #148 (got 3 columns instead of 2)
#     Line #149 (got 3 columns instead of 2)
#     Line #150 (got 3 columns instead of 2)
#     Line #151 (got 1 columns instead of 2)
#     Line #153 (got 5 columns instead of 2)
#     Line #154 (got 24 columns instead of 2)
#     Line #155 (got 22 columns instead of 2)
#     Line #156 (got 1 columns instead of 2)
#     Line #157 (got 1 columns instead of 2)
#     Line #158 (got 1 columns instead of 2)
#     Line #159 (got 1 columns instead of 2)
#     Line #160 (got 4 columns instead of 2)
#     Line #161 (got 13 columns instead of 2)
#     Line #162 (got 1 columns instead of 2)
#     Line #164 (got 11 columns instead of 2)
#     Line #165 (got 5 columns instead of 2)
#     Line #166 (got 8 columns instead of 2)
#     Line #167 (got 1 columns instead of 2)
#     Line #168 (got 11 columns instead of 2)
#     Line #170 (got 1 columns instead of 2)
#     Line #171 (got 1 columns instead of 2)
#     Line #173 (got 12 columns instead of 2)
#     Line #174 (got 3 columns instead of 2)
#     Line #175 (got 22 columns instead of 2)
#     Line #176 (got 1 columns instead of 2)
#     Line #178 (got 10 columns instead of 2)
#     Line #179 (got 3 columns instead of 2)
#     Line #180 (got 15 columns instead of 2)
#     Line #181 (got 15 columns instead of 2)
#     Line #182 (got 15 columns instead of 2)
#     Line #183 (got 17 columns instead of 2)
#     Line #184 (got 19 columns instead of 2)
#     Line #185 (got 1 columns instead of 2)
#     Line #187 (got 10 columns instead of 2)
#     Line #188 (got 3 columns instead of 2)
#     Line #189 (got 15 columns instead of 2)
#     Line #190 (got 17 columns instead of 2)
#     Line #191 (got 18 columns instead of 2)
#     Line #192 (got 1 columns instead of 2)
#     Line #193 (got 1 columns instead of 2)
#     Line #194 (got 1 columns instead of 2)
#     Line #195 (got 1 columns instead of 2)
#     Line #197 (got 4 columns instead of 2)
#     Line #198 (got 13 columns instead of 2)
#     Line #199 (got 1 columns instead of 2)
#     Line #201 (got 11 columns instead of 2)
#     Line #202 (got 5 columns instead of 2)
#     Line #203 (got 8 columns instead of 2)
#     Line #204 (got 1 columns instead of 2)
#     Line #205 (got 11 columns instead of 2)
#     Line #207 (got 1 columns instead of 2)
#     Line #208 (got 1 columns instead of 2)
#     Line #210 (got 12 columns instead of 2)
#     Line #211 (got 20 columns instead of 2)
#     Line #213 (got 3 columns instead of 2)
#     Line #214 (got 3 columns instead of 2)
#     Line #215 (got 17 columns instead of 2)
#     Line #216 (got 1 columns instead of 2)
#     Line #218 (got 5 columns instead of 2)
#     Line #219 (got 22 columns instead of 2)
#     Line #220 (got 23 columns instead of 2)
#     Line #221 (got 1 columns instead of 2)
#     Line #222 (got 1 columns instead of 2)
#     Line #223 (got 1 columns instead of 2)
#     Line #224 (got 1 columns instead of 2)
#     Line #225 (got 1 columns instead of 2)
#     Line #226 (got 1 columns instead of 2)
#     Line #228 (got 6 columns instead of 2)
#     Line #229 (got 3 columns instead of 2)
#     Line #230 (got 8 columns instead of 2)
#     Line #231 (got 1 columns instead of 2)
#     Line #232 (got 1 columns instead of 2)
#     Line #233 (got 4 columns instead of 2)
#     Line #234 (got 1 columns instead of 2)
#     Line #235 (got 1 columns instead of 2)
#     Line #236 (got 1 columns instead of 2)
#     Line #238 (got 18 columns instead of 2)
#     Line #239 (got 11 columns instead of 2)
#     Line #241 (got 8 columns instead of 2)
#     Line #242 (got 1 columns instead of 2)
#     Line #243 (got 1 columns instead of 2)
#     Line #244 (got 1 columns instead of 2)
#     Line #245 (got 1 columns instead of 2)
#     Line #247 (got 1 columns instead of 2)
#     Line #248 (got 1 columns instead of 2)
#     Line #249 (got 1 columns instead of 2)
#     Line #250 (got 1 columns instead of 2)
#     Line #251 (got 1 columns instead of 2)
#     Line #252 (got 1 columns instead of 2)
#     Line #253 (got 1 columns instead of 2)
#     Line #254 (got 1 columns instead of 2)
#     Line #255 (got 1 columns instead of 2)
#     Line #256 (got 5 columns instead of 2)
#     Line #257 (got 5 columns instead of 2)
#     Line #259 (got 7 columns instead of 2)
#     Line #261 (got 3 columns instead of 2)
#     Line #264 (got 10 columns instead of 2)
#     Line #265 (got 11 columns instead of 2)
#     Line #266 (got 7 columns instead of 2)
#     Line #267 (got 31 columns instead of 2)
#     Line #268 (got 42 columns instead of 2)
#     Line #269 (got 56 columns instead of 2)
#     Line #270 (got 1 columns instead of 2)
#     Line #272 (got 11 columns instead of 2)
#     Line #274 (got 9 columns instead of 2)
#     Line #275 (got 1 columns instead of 2)
#     Line #277 (got 11 columns instead of 2)
#     Line #278 (got 6 columns instead of 2)
#     Line #279 (got 3 columns instead of 2)
#     Line #280 (got 1 columns instead of 2)
#     Line #281 (got 7 columns instead of 2)
#     Line #283 (got 1 columns instead of 2)
#     Line #284 (got 5 columns instead of 2)
#     Line #285 (got 1 columns instead of 2)
#     Line #287 (got 13 columns instead of 2)
#     Line #289 (got 4 columns instead of 2)
#     Line #290 (got 1 columns instead of 2)
#     Line #291 (got 1 columns instead of 2)
#     Line #292 (got 1 columns instead of 2)
#     Line #294 (got 1 columns instead of 2)
#     Line #296 (got 3 columns instead of 2)
#     Line #297 (got 8 columns instead of 2)
#     Line #298 (got 6 columns instead of 2)
#     Line #299 (got 1 columns instead of 2)
#     Line #300 (got 1 columns instead of 2)
#     Line #302 (got 8 columns instead of 2)
#     Line #305 (got 11 columns instead of 2)
#     Line #306 (got 11 columns instead of 2)
#     Line #307 (got 7 columns instead of 2)
#     Line #308 (got 31 columns instead of 2)
#     Line #309 (got 42 columns instead of 2)
#     Line #310 (got 56 columns instead of 2)
#     Line #311 (got 1 columns instead of 2)
#     Line #313 (got 11 columns instead of 2)
#     Line #315 (got 9 columns instead of 2)
#     Line #316 (got 1 columns instead of 2)
#     Line #318 (got 11 columns instead of 2)
#     Line #319 (got 6 columns instead of 2)
#     Line #320 (got 3 columns instead of 2)
#     Line #321 (got 1 columns instead of 2)
#     Line #322 (got 7 columns instead of 2)
#     Line #324 (got 1 columns instead of 2)
#     Line #325 (got 5 columns instead of 2)
#     Line #326 (got 1 columns instead of 2)
#     Line #328 (got 13 columns instead of 2)
#     Line #330 (got 4 columns instead of 2)
#     Line #331 (got 1 columns instead of 2)
#     Line #332 (got 1 columns instead of 2)
#     Line #333 (got 1 columns instead of 2)
#     Line #337 (got 11 columns instead of 2)
#     Line #338 (got 11 columns instead of 2)
#     Line #339 (got 7 columns instead of 2)
#     Line #340 (got 31 columns instead of 2)
#     Line #341 (got 42 columns instead of 2)
#     Line #342 (got 56 columns instead of 2)
#     Line #343 (got 1 columns instead of 2)
#     Line #345 (got 11 columns instead of 2)
#     Line #347 (got 9 columns instead of 2)
#     Line #348 (got 1 columns instead of 2)
#     Line #350 (got 11 columns instead of 2)
#     Line #351 (got 6 columns instead of 2)
#     Line #352 (got 3 columns instead of 2)
#     Line #353 (got 1 columns instead of 2)
#     Line #354 (got 7 columns instead of 2)
#     Line #356 (got 1 columns instead of 2)
#     Line #357 (got 5 columns instead of 2)
#     Line #358 (got 1 columns instead of 2)
#     Line #360 (got 13 columns instead of 2)
#     Line #362 (got 4 columns instead of 2)
#     Line #363 (got 1 columns instead of 2)
#     Line #364 (got 1 columns instead of 2)
#     Line #365 (got 1 columns instead of 2)
#     Line #368 (got 1 columns instead of 2)
#     Line #370 (got 1 columns instead of 2)
#     Line #371 (got 1 columns instead of 2)
#     Line #373 (got 1 columns instead of 2)
#     Line #375 (got 1 columns instead of 2)
#     Line #377 (got 16 columns instead of 2)
#     Line #378 (got 1 columns instead of 2)
#     Line #379 (got 22 columns instead of 2)
#     Line #380 (got 1 columns instead of 2)
#     Line #382 (got 1 columns instead of 2)
#     Line #383 (got 1 columns instead of 2)
#     Line #384 (got 1 columns instead of 2)
#     Line #386 (got 1 columns instead of 2)
#     Line #388 (got 3 columns instead of 2)
#     Line #392 (got 1 columns instead of 2)
#     Line #396 (got 4 columns instead of 2)
#     Line #397 (got 4 columns instead of 2)
#     Line #398 (got 4 columns instead of 2)
#     Line #409 (got 7 columns instead of 2)
#     Line #410 (got 4 columns instead of 2)
#     Line #416 (got 1 columns instead of 2)
#     Line #417 (got 22 columns instead of 2)
#     Line #418 (got 55 columns instead of 2)
#     Line #419 (got 1 columns instead of 2)
#     Line #420 (got 4 columns instead of 2)
#     Line #421 (got 6 columns instead of 2)
#     Line #422 (got 1 columns instead of 2)
#     Line #423 (got 1 columns instead of 2)
#     Line #425 (got 1 columns instead of 2)
#     Line #427 (got 1 columns instead of 2)
#     Line #428 (got 20 columns instead of 2)
#     Line #429 (got 27 columns instead of 2)
#     Line #430 (got 1 columns instead of 2)
#     Line #431 (got 1 columns instead of 2)
#     Line #432 (got 4 columns instead of 2)
#     Line #433 (got 5 columns instead of 2)
#     Line #434 (got 1 columns instead of 2)
#     Line #435 (got 1 columns instead of 2)
#     Line #437 (got 1 columns instead of 2)
#     Line #439 (got 1 columns instead of 2)
#     Line #440 (got 22 columns instead of 2)
#     Line #441 (got 88 columns instead of 2)
#     Line #442 (got 1 columns instead of 2)
#     Line #443 (got 1 columns instead of 2)
#     Line #444 (got 3 columns instead of 2)
#     Line #445 (got 5 columns instead of 2)
#     Line #446 (got 1 columns instead of 2)
#     Line #447 (got 1 columns instead of 2)
#     Line #448 (got 1 columns instead of 2)
#     Line #449 (got 1 columns instead of 2)
#     Line #451 (got 3 columns instead of 2)
#     Line #452 (got 26 columns instead of 2)
#     Line #453 (got 11 columns instead of 2)
#     Line #455 (got 3 columns instead of 2)
#     Line #457 (got 1 columns instead of 2)
#     Line #459 (got 1 columns instead of 2)
#     Line #461 (got 5 columns instead of 2)
#     Line #462 (got 1 columns instead of 2)
#     Line #463 (got 1 columns instead of 2)
#     Line #464 (got 1 columns instead of 2)
#     Line #465 (got 1 columns instead of 2)
#     Line #467 (got 4 columns instead of 2)
#     Line #468 (got 17 columns instead of 2)
#     Line #469 (got 35 columns instead of 2)
#     Line #471 (got 3 columns instead of 2)
#     Line #474 (got 4 columns instead of 2)
#     Line #475 (got 11 columns instead of 2)
#     Line #476 (got 42 columns instead of 2)
#     Line #479 (got 3 columns instead of 2)
#     Line #482 (got 4 columns instead of 2)
#     Line #483 (got 10 columns instead of 2)
#     Line #484 (got 87 columns instead of 2)
#     Line #485 (got 3 columns instead of 2)
#     Line #487 (got 3 columns instead of 2)
#     Line #491 (got 10 columns instead of 2)
#     Line #492 (got 37 columns instead of 2)
#     Line #493 (got 1 columns instead of 2)
#     Line #494 (got 3 columns instead of 2)
#     Line #495 (got 1 columns instead of 2)
#     Line #498 (got 12 columns instead of 2)
#     Line #499 (got 17 columns instead of 2)
#     Line #500 (got 1 columns instead of 2)
#     Line #501 (got 1 columns instead of 2)
#     Line #503 (got 1 columns instead of 2)
#     Line #506 (got 1 columns instead of 2)
#     Line #507 (got 5 columns instead of 2)
#     Line #508 (got 3 columns instead of 2)
#     Line #516 (got 5 columns instead of 2)
#     Line #518 (got 6 columns instead of 2)
#     Line #520 (got 3 columns instead of 2)
#     Line #521 (got 6 columns instead of 2)
#     Line #523 (got 11 columns instead of 2)
#     Line #524 (got 15 columns instead of 2)
#     Line #525 (got 1 columns instead of 2)
#     Line #526 (got 1 columns instead of 2)
#     Line #527 (got 5 columns instead of 2)
#     Line #528 (got 23 columns instead of 2)
#     Line #529 (got 18 columns instead of 2)
#     Line #530 (got 1 columns instead of 2)
#     Line #531 (got 1 columns instead of 2)
#     Line #532 (got 1 columns instead of 2)
#     Line #535 (got 5 columns instead of 2)
#     Line #537 (got 5 columns instead of 2)
#     Line #538 (got 5 columns instead of 2)
#     Line #539 (got 1 columns instead of 2)
#     Line #541 (got 4 columns instead of 2)
#     Line #542 (got 1 columns instead of 2)
#     Line #544 (got 1 columns instead of 2)
#     Line #546 (got 7 columns instead of 2)
#     Line #547 (got 3 columns instead of 2)
#     Line #548 (got 71 columns instead of 2)
#     Line #549 (got 1 columns instead of 2)
#     Line #550 (got 1 columns instead of 2)
#     Line #551 (got 1 columns instead of 2)
#     Line #553 (got 5 columns instead of 2)
#     Line #554 (got 12 columns instead of 2)
#     Line #555 (got 1 columns instead of 2)
#     Line #558 (got 4 columns instead of 2)
#     Line #559 (got 1 columns instead of 2)
#     Line #560 (got 1 columns instead of 2)
#     Line #562 (got 1 columns instead of 2)
#     Line #563 (got 5 columns instead of 2)
#     Line #565 (got 1 columns instead of 2)
#     Line #566 (got 1 columns instead of 2)
#     Line #567 (got 1 columns instead of 2)
#     Line #571 (got 5 columns instead of 2)
#     Line #572 (got 4 columns instead of 2)
#     Line #574 (got 1 columns instead of 2)
#     Line #576 (got 5 columns instead of 2)
#     Line #577 (got 8 columns instead of 2)
#     Line #578 (got 9 columns instead of 2)
#     Line #579 (got 1 columns instead of 2)
#     Line #580 (got 1 columns instead of 2)
#     Line #585 (got 4 columns instead of 2)
#     Line #587 (got 6 columns instead of 2)
#     Line #589 (got 3 columns instead of 2)
#     Line #590 (got 4 columns instead of 2)
#     Line #593 (got 1 columns instead of 2)
#     Line #598 (got 6 columns instead of 2)
#     Line #599 (got 7 columns instead of 2)
#     Line #600 (got 6 columns instead of 2)
#     Line #601 (got 1 columns instead of 2)
#     Line #604 (got 1 columns instead of 2)
#     Line #606 (got 6 columns instead of 2)
#     Line #607 (got 10 columns instead of 2)
#     Line #608 (got 28 columns instead of 2)
#     Line #609 (got 1 columns instead of 2)
#     Line #610 (got 7 columns instead of 2)
#     Line #611 (got 10 columns instead of 2)
#     Line #612 (got 35 columns instead of 2)
#     Line #613 (got 1 columns instead of 2)
#     Line #614 (got 1 columns instead of 2)
#     Line #615 (got 1 columns instead of 2)
#     Line #616 (got 1 columns instead of 2)
#     Line #620 (got 21 columns instead of 2)
#     Line #621 (got 1 columns instead of 2)
#     Line #623 (got 8 columns instead of 2)
#     Line #625 (got 5 columns instead of 2)
#     Line #626 (got 1 columns instead of 2)
#     Line #627 (got 5 columns instead of 2)
#     Line #628 (got 65 columns instead of 2)
#     Line #629 (got 1 columns instead of 2)
#     Line #630 (got 1 columns instead of 2)
#     Line #631 (got 5 columns instead of 2)
#     Line #632 (got 65 columns instead of 2)
#     Line #633 (got 1 columns instead of 2)
#     Line #634 (got 1 columns instead of 2)
#     Line #635 (got 5 columns instead of 2)
#     Line #636 (got 65 columns instead of 2)
#     Line #637 (got 1 columns instead of 2)
#     Line #638 (got 1 columns instead of 2)
#     Line #639 (got 5 columns instead of 2)
#     Line #640 (got 65 columns instead of 2)
#     Line #641 (got 1 columns instead of 2)
#     Line #642 (got 1 columns instead of 2)
#     Line #643 (got 5 columns instead of 2)
#     Line #644 (got 65 columns instead of 2)
#     Line #645 (got 1 columns instead of 2)
#     Line #646 (got 1 columns instead of 2)
#     Line #647 (got 5 columns instead of 2)
#     Line #648 (got 65 columns instead of 2)
#     Line #649 (got 1 columns instead of 2)
#     Line #650 (got 1 columns instead of 2)
#     Line #651 (got 5 columns instead of 2)
#     Line #652 (got 65 columns instead of 2)
#     Line #653 (got 1 columns instead of 2)
#     Line #654 (got 1 columns instead of 2)
#     Line #655 (got 5 columns instead of 2)
#     Line #656 (got 65 columns instead of 2)
#     Line #657 (got 1 columns instead of 2)
#     Line #658 (got 1 columns instead of 2)
#     Line #659 (got 5 columns instead of 2)
#     Line #660 (got 65 columns instead of 2)
#     Line #661 (got 1 columns instead of 2)
#     Line #662 (got 1 columns instead of 2)
#     Line #663 (got 5 columns instead of 2)
#     Line #664 (got 65 columns instead of 2)
#     Line #665 (got 1 columns instead of 2)
#     Line #666 (got 1 columns instead of 2)
#     Line #667 (got 5 columns instead of 2)
#     Line #668 (got 65 columns instead of 2)
#     Line #669 (got 1 columns instead of 2)
#     Line #670 (got 1 columns instead of 2)
#     Line #671 (got 5 columns instead of 2)
#     Line #672 (got 65 columns instead of 2)
#     Line #673 (got 1 columns instead of 2)
#     Line #674 (got 1 columns instead of 2)
#     Line #675 (got 5 columns instead of 2)
#     Line #676 (got 65 columns instead of 2)
#     Line #677 (got 1 columns instead of 2)
#     Line #678 (got 1 columns instead of 2)
#     Line #679 (got 5 columns instead of 2)
#     Line #680 (got 65 columns instead of 2)
#     Line #681 (got 1 columns instead of 2)
#     Line #682 (got 1 columns instead of 2)
#     Line #683 (got 5 columns instead of 2)
#     Line #684 (got 65 columns instead of 2)
#     Line #685 (got 1 columns instead of 2)
#     Line #686 (got 1 columns instead of 2)
#     Line #687 (got 5 columns instead of 2)
#     Line #688 (got 65 columns instead of 2)
#     Line #689 (got 1 columns instead of 2)
#     Line #690 (got 1 columns instead of 2)
#     Line #691 (got 5 columns instead of 2)
#     Line #692 (got 65 columns instead of 2)
#     Line #693 (got 1 columns instead of 2)
#     Line #694 (got 1 columns instead of 2)
#     Line #695 (got 5 columns instead of 2)
#     Line #696 (got 65 columns instead of 2)
#     Line #697 (got 1 columns instead of 2)
#     Line #698 (got 1 columns instead of 2)
#     Line #699 (got 5 columns instead of 2)
#     Line #700 (got 65 columns instead of 2)
#     Line #701 (got 1 columns instead of 2)
#     Line #702 (got 1 columns instead of 2)
#     Line #703 (got 5 columns instead of 2)
#     Line #704 (got 65 columns instead of 2)
#     Line #705 (got 1 columns instead of 2)
#     Line #706 (got 1 columns instead of 2)
#     Line #707 (got 5 columns instead of 2)
#     Line #708 (got 65 columns instead of 2)
#     Line #709 (got 1 columns instead of 2)
#     Line #710 (got 1 columns instead of 2)
#     Line #711 (got 5 columns instead of 2)
#     Line #712 (got 65 columns instead of 2)
#     Line #713 (got 1 columns instead of 2)
#     Line #714 (got 1 columns instead of 2)
#     Line #715 (got 5 columns instead of 2)
#     Line #716 (got 65 columns instead of 2)
#     Line #717 (got 1 columns instead of 2)
#     Line #718 (got 1 columns instead of 2)
#     Line #719 (got 5 columns instead of 2)
#     Line #720 (got 65 columns instead of 2)
#     Line #721 (got 1 columns instead of 2)
#     Line #722 (got 1 columns instead of 2)
#     Line #723 (got 5 columns instead of 2)
#     Line #724 (got 65 columns instead of 2)
#     Line #725 (got 1 columns instead of 2)
#     Line #726 (got 1 columns instead of 2)
#     Line #727 (got 5 columns instead of 2)
#     Line #728 (got 65 columns instead of 2)
#     Line #729 (got 1 columns instead of 2)
#     Line #730 (got 1 columns instead of 2)
#     Line #731 (got 5 columns instead of 2)
#     Line #732 (got 65 columns instead of 2)
#     Line #733 (got 1 columns instead of 2)
#     Line #734 (got 1 columns instead of 2)
#     Line #735 (got 5 columns instead of 2)
#     Line #736 (got 65 columns instead of 2)
#     Line #737 (got 1 columns instead of 2)
#     Line #738 (got 1 columns instead of 2)
#     Line #739 (got 5 columns instead of 2)
#     Line #740 (got 65 columns instead of 2)
#     Line #741 (got 1 columns instead of 2)
#     Line #742 (got 1 columns instead of 2)
#     Line #743 (got 5 columns instead of 2)
#     Line #744 (got 65 columns instead of 2)
#     Line #745 (got 1 columns instead of 2)
#     Line #746 (got 1 columns instead of 2)
#     Line #747 (got 5 columns instead of 2)
#     Line #748 (got 65 columns instead of 2)
#     Line #749 (got 1 columns instead of 2)
#     Line #750 (got 1 columns instead of 2)
#     Line #751 (got 5 columns instead of 2)
#     Line #752 (got 65 columns instead of 2)
#     Line #753 (got 1 columns instead of 2)
#     Line #754 (got 1 columns instead of 2)
#     Line #755 (got 5 columns instead of 2)
#     Line #756 (got 65 columns instead of 2)
#     Line #757 (got 1 columns instead of 2)
#     Line #758 (got 1 columns instead of 2)
#     Line #759 (got 5 columns instead of 2)
#     Line #760 (got 65 columns instead of 2)
#     Line #761 (got 1 columns instead of 2)
#     Line #762 (got 1 columns instead of 2)
#     Line #763 (got 5 columns instead of 2)
#     Line #764 (got 65 columns instead of 2)
#     Line #765 (got 1 columns instead of 2)
#     Line #766 (got 1 columns instead of 2)
#     Line #767 (got 5 columns instead of 2)
#     Line #768 (got 65 columns instead of 2)
#     Line #769 (got 1 columns instead of 2)
#     Line #770 (got 1 columns instead of 2)
#     Line #771 (got 5 columns instead of 2)
#     Line #772 (got 65 columns instead of 2)
#     Line #773 (got 1 columns instead of 2)
#     Line #774 (got 1 columns instead of 2)
#     Line #775 (got 5 columns instead of 2)
#     Line #776 (got 65 columns instead of 2)
#     Line #777 (got 1 columns instead of 2)
#     Line #778 (got 1 columns instead of 2)
#     Line #779 (got 5 columns instead of 2)
#     Line #780 (got 65 columns instead of 2)
#     Line #781 (got 1 columns instead of 2)
#     Line #782 (got 1 columns instead of 2)
#     Line #783 (got 5 columns instead of 2)
#     Line #784 (got 65 columns instead of 2)
#     Line #785 (got 1 columns instead of 2)
#     Line #786 (got 1 columns instead of 2)
#     Line #787 (got 5 columns instead of 2)
#     Line #788 (got 65 columns instead of 2)
#     Line #789 (got 1 columns instead of 2)
#     Line #790 (got 1 columns instead of 2)
#     Line #791 (got 5 columns instead of 2)
#     Line #792 (got 65 columns instead of 2)
#     Line #793 (got 1 columns instead of 2)
#     Line #794 (got 1 columns instead of 2)
#     Line #795 (got 5 columns instead of 2)
#     Line #796 (got 65 columns instead of 2)
#     Line #797 (got 1 columns instead of 2)
#     Line #798 (got 1 columns instead of 2)
#     Line #799 (got 5 columns instead of 2)
#     Line #800 (got 65 columns instead of 2)
#     Line #801 (got 1 columns instead of 2)
#     Line #802 (got 1 columns instead of 2)
#     Line #803 (got 5 columns instead of 2)
#     Line #804 (got 65 columns instead of 2)
#     Line #805 (got 1 columns instead of 2)
#     Line #806 (got 1 columns instead of 2)
#     Line #807 (got 5 columns instead of 2)
#     Line #808 (got 65 columns instead of 2)
#     Line #809 (got 1 columns instead of 2)
#     Line #810 (got 1 columns instead of 2)
#     Line #811 (got 5 columns instead of 2)
#     Line #812 (got 65 columns instead of 2)
#     Line #813 (got 1 columns instead of 2)
#     Line #814 (got 1 columns instead of 2)
#     Line #815 (got 5 columns instead of 2)
#     Line #816 (got 65 columns instead of 2)
#     Line #817 (got 1 columns instead of 2)
#     Line #818 (got 1 columns instead of 2)
#     Line #819 (got 5 columns instead of 2)
#     Line #820 (got 65 columns instead of 2)
#     Line #821 (got 1 columns instead of 2)
#     Line #822 (got 1 columns instead of 2)
#     Line #823 (got 5 columns instead of 2)
#     Line #824 (got 65 columns instead of 2)
#     Line #825 (got 1 columns instead of 2)
#     Line #826 (got 1 columns instead of 2)
#     Line #827 (got 5 columns instead of 2)
#     Line #828 (got 65 columns instead of 2)
#     Line #829 (got 1 columns instead of 2)
#     Line #830 (got 1 columns instead of 2)
#     Line #831 (got 5 columns instead of 2)
#     Line #832 (got 65 columns instead of 2)
#     Line #833 (got 1 columns instead of 2)
#     Line #834 (got 1 columns instead of 2)
#     Line #835 (got 5 columns instead of 2)
#     Line #836 (got 65 columns instead of 2)
#     Line #837 (got 1 columns instead of 2)
#     Line #838 (got 1 columns instead of 2)
#     Line #839 (got 5 columns instead of 2)
#     Line #840 (got 65 columns instead of 2)
#     Line #841 (got 1 columns instead of 2)
#     Line #842 (got 1 columns instead of 2)
#     Line #843 (got 5 columns instead of 2)
#     Line #844 (got 65 columns instead of 2)
#     Line #845 (got 1 columns instead of 2)
#     Line #846 (got 1 columns instead of 2)
#     Line #847 (got 5 columns instead of 2)
#     Line #848 (got 65 columns instead of 2)
#     Line #849 (got 1 columns instead of 2)
#     Line #850 (got 1 columns instead of 2)
#     Line #851 (got 5 columns instead of 2)
#     Line #852 (got 65 columns instead of 2)
#     Line #853 (got 1 columns instead of 2)
#     Line #854 (got 1 columns instead of 2)
#     Line #855 (got 5 columns instead of 2)
#     Line #856 (got 65 columns instead of 2)
#     Line #857 (got 1 columns instead of 2)
#     Line #858 (got 1 columns instead of 2)
#     Line #859 (got 5 columns instead of 2)
#     Line #860 (got 65 columns instead of 2)
#     Line #861 (got 1 columns instead of 2)
#     Line #862 (got 1 columns instead of 2)
#     Line #863 (got 5 columns instead of 2)
#     Line #864 (got 65 columns instead of 2)
#     Line #865 (got 1 columns instead of 2)
#     Line #866 (got 1 columns instead of 2)
#     Line #867 (got 5 columns instead of 2)
#     Line #868 (got 65 columns instead of 2)
#     Line #869 (got 1 columns instead of 2)
#     Line #870 (got 1 columns instead of 2)
#     Line #871 (got 5 columns instead of 2)
#     Line #872 (got 65 columns instead of 2)
#     Line #873 (got 1 columns instead of 2)
#     Line #874 (got 1 columns instead of 2)
#     Line #875 (got 5 columns instead of 2)
#     Line #876 (got 65 columns instead of 2)
#     Line #877 (got 1 columns instead of 2)
#     Line #878 (got 1 columns instead of 2)
#     Line #879 (got 5 columns instead of 2)
#     Line #880 (got 65 columns instead of 2)
#     Line #881 (got 1 columns instead of 2)
#     Line #882 (got 1 columns instead of 2)
#     Line #883 (got 5 columns instead of 2)
#     Line #884 (got 65 columns instead of 2)
#     Line #885 (got 1 columns instead of 2)
#     Line #886 (got 1 columns instead of 2)
#     Line #887 (got 5 columns instead of 2)
#     Line #888 (got 65 columns instead of 2)
#     Line #889 (got 1 columns instead of 2)
#     Line #890 (got 1 columns instead of 2)
#     Line #891 (got 5 columns instead of 2)
#     Line #892 (got 65 columns instead of 2)
#     Line #893 (got 1 columns instead of 2)
#     Line #894 (got 1 columns instead of 2)
#     Line #895 (got 5 columns instead of 2)
#     Line #896 (got 65 columns instead of 2)
#     Line #897 (got 1 columns instead of 2)
#     Line #898 (got 1 columns instead of 2)
#     Line #899 (got 5 columns instead of 2)
#     Line #900 (got 65 columns instead of 2)
#     Line #901 (got 1 columns instead of 2)
#     Line #902 (got 1 columns instead of 2)
#     Line #903 (got 5 columns instead of 2)
#     Line #904 (got 65 columns instead of 2)
#     Line #905 (got 1 columns instead of 2)
#     Line #906 (got 1 columns instead of 2)
#     Line #907 (got 5 columns instead of 2)
#     Line #908 (got 65 columns instead of 2)
#     Line #909 (got 1 columns instead of 2)
#     Line #910 (got 1 columns instead of 2)
#     Line #911 (got 5 columns instead of 2)
#     Line #912 (got 65 columns instead of 2)
#     Line #913 (got 1 columns instead of 2)
#     Line #914 (got 1 columns instead of 2)
#     Line #915 (got 5 columns instead of 2)
#     Line #916 (got 65 columns instead of 2)
#     Line #917 (got 1 columns instead of 2)
#     Line #918 (got 1 columns instead of 2)
#     Line #919 (got 5 columns instead of 2)
#     Line #920 (got 65 columns instead of 2)
#     Line #921 (got 1 columns instead of 2)
#     Line #922 (got 1 columns instead of 2)
#     Line #923 (got 5 columns instead of 2)
#     Line #924 (got 65 columns instead of 2)
#     Line #925 (got 1 columns instead of 2)
#     Line #926 (got 1 columns instead of 2)
#     Line #927 (got 5 columns instead of 2)
#     Line #928 (got 65 columns instead of 2)
#     Line #929 (got 1 columns instead of 2)
#     Line #930 (got 1 columns instead of 2)
#     Line #931 (got 5 columns instead of 2)
#     Line #932 (got 65 columns instead of 2)
#     Line #933 (got 1 columns instead of 2)
#     Line #934 (got 1 columns instead of 2)
#     Line #935 (got 5 columns instead of 2)
#     Line #936 (got 65 columns instead of 2)
#     Line #937 (got 1 columns instead of 2)
#     Line #938 (got 1 columns instead of 2)
#     Line #939 (got 5 columns instead of 2)
#     Line #940 (got 65 columns instead of 2)
#     Line #941 (got 1 columns instead of 2)
#     Line #942 (got 1 columns instead of 2)
#     Line #943 (got 5 columns instead of 2)
#     Line #944 (got 65 columns instead of 2)
#     Line #945 (got 1 columns instead of 2)
#     Line #946 (got 1 columns instead of 2)
#     Line #947 (got 5 columns instead of 2)
#     Line #948 (got 65 columns instead of 2)
#     Line #949 (got 1 columns instead of 2)
#     Line #950 (got 1 columns instead of 2)
#     Line #951 (got 5 columns instead of 2)
#     Line #952 (got 65 columns instead of 2)
#     Line #953 (got 1 columns instead of 2)
#     Line #954 (got 1 columns instead of 2)
#     Line #955 (got 5 columns instead of 2)
#     Line #956 (got 65 columns instead of 2)
#     Line #957 (got 1 columns instead of 2)
#     Line #958 (got 1 columns instead of 2)
#     Line #959 (got 5 columns instead of 2)
#     Line #960 (got 65 columns instead of 2)
#     Line #961 (got 1 columns instead of 2)
#     Line #962 (got 1 columns instead of 2)
#     Line #963 (got 5 columns instead of 2)
#     Line #964 (got 65 columns instead of 2)
#     Line #965 (got 1 columns instead of 2)
#     Line #966 (got 1 columns instead of 2)
#     Line #967 (got 5 columns instead of 2)
#     Line #968 (got 65 columns instead of 2)
#     Line #969 (got 1 columns instead of 2)
#     Line #970 (got 1 columns instead of 2)
#     Line #971 (got 5 columns instead of 2)
#     Line #972 (got 65 columns instead of 2)
#     Line #973 (got 1 columns instead of 2)
#     Line #974 (got 1 columns instead of 2)
#     Line #975 (got 5 columns instead of 2)
#     Line #976 (got 65 columns instead of 2)
#     Line #977 (got 1 columns instead of 2)
#     Line #978 (got 1 columns instead of 2)
#     Line #979 (got 5 columns instead of 2)
#     Line #980 (got 65 columns instead of 2)
#     Line #981 (got 1 columns instead of 2)
#     Line #982 (got 1 columns instead of 2)
#     Line #983 (got 5 columns instead of 2)
#     Line #984 (got 65 columns instead of 2)
#     Line #985 (got 1 columns instead of 2)
#     Line #986 (got 1 columns instead of 2)
#     Line #987 (got 5 columns instead of 2)
#     Line #988 (got 65 columns instead of 2)
#     Line #989 (got 1 columns instead of 2)
#     Line #990 (got 1 columns instead of 2)
#     Line #991 (got 5 columns instead of 2)
#     Line #992 (got 65 columns instead of 2)
#     Line #993 (got 1 columns instead of 2)
#     Line #994 (got 1 columns instead of 2)
#     Line #995 (got 5 columns instead of 2)
#     Line #996 (got 65 columns instead of 2)
#     Line #997 (got 1 columns instead of 2)
#     Line #998 (got 1 columns instead of 2)
#     Line #999 (got 5 columns instead of 2)
#     Line #1000 (got 65 columns instead of 2)
#     Line #1001 (got 1 columns instead of 2)
#     Line #1002 (got 1 columns instead of 2)
#     Line #1003 (got 5 columns instead of 2)
#     Line #1004 (got 65 columns instead of 2)
#     Line #1005 (got 1 columns instead of 2)
#     Line #1006 (got 1 columns instead of 2)
#     Line #1007 (got 5 columns instead of 2)
#     Line #1008 (got 65 columns instead of 2)
#     Line #1009 (got 1 columns instead of 2)
#     Line #1010 (got 1 columns instead of 2)
#     Line #1011 (got 5 columns instead of 2)
#     Line #1012 (got 65 columns instead of 2)
#     Line #1013 (got 1 columns instead of 2)
#     Line #1014 (got 1 columns instead of 2)
#     Line #1015 (got 5 columns instead of 2)
#     Line #1016 (got 65 columns instead of 2)
#     Line #1017 (got 1 columns instead of 2)
#     Line #1018 (got 1 columns instead of 2)
#     Line #1019 (got 5 columns instead of 2)
#     Line #1020 (got 65 columns instead of 2)
#     Line #1021 (got 1 columns instead of 2)
#     Line #1022 (got 1 columns instead of 2)
#     Line #1023 (got 5 columns instead of 2)
#     Line #1024 (got 65 columns instead of 2)
#     Line #1025 (got 1 columns instead of 2)
#     Line #1026 (got 1 columns instead of 2)
#     Line #1027 (got 5 columns instead of 2)
#     Line #1028 (got 65 columns instead of 2)
#     Line #1029 (got 1 columns instead of 2)
#     Line #1030 (got 1 columns instead of 2)
#     Line #1031 (got 5 columns instead of 2)
#     Line #1032 (got 65 columns instead of 2)
#     Line #1033 (got 1 columns instead of 2)
#     Line #1034 (got 1 columns instead of 2)
#     Line #1035 (got 5 columns instead of 2)
#     Line #1036 (got 65 columns instead of 2)
#     Line #1037 (got 1 columns instead of 2)
#     Line #1038 (got 1 columns instead of 2)
#     Line #1039 (got 5 columns instead of 2)
#     Line #1040 (got 65 columns instead of 2)
#     Line #1041 (got 1 columns instead of 2)
#     Line #1042 (got 1 columns instead of 2)
#     Line #1043 (got 5 columns instead of 2)
#     Line #1044 (got 65 columns instead of 2)
#     Line #1045 (got 1 columns instead of 2)
#     Line #1046 (got 1 columns instead of 2)
#     Line #1047 (got 5 columns instead of 2)
#     Line #1048 (got 65 columns instead of 2)
#     Line #1049 (got 1 columns instead of 2)
#     Line #1050 (got 1 columns instead of 2)
#     Line #1051 (got 5 columns instead of 2)
#     Line #1052 (got 65 columns instead of 2)
#     Line #1053 (got 1 columns instead of 2)
#     Line #1054 (got 1 columns instead of 2)
#     Line #1055 (got 5 columns instead of 2)
#     Line #1056 (got 65 columns instead of 2)
#     Line #1057 (got 1 columns instead of 2)
#     Line #1058 (got 1 columns instead of 2)
#     Line #1059 (got 5 columns instead of 2)
#     Line #1060 (got 65 columns instead of 2)
#     Line #1061 (got 1 columns instead of 2)
#     Line #1062 (got 1 columns instead of 2)
#     Line #1063 (got 5 columns instead of 2)
#     Line #1064 (got 65 columns instead of 2)
#     Line #1065 (got 1 columns instead of 2)
#     Line #1066 (got 1 columns instead of 2)
#     Line #1067 (got 5 columns instead of 2)
#     Line #1068 (got 65 columns instead of 2)
#     Line #1069 (got 1 columns instead of 2)
#     Line #1070 (got 1 columns instead of 2)
#     Line #1071 (got 5 columns instead of 2)
#     Line #1072 (got 65 columns instead of 2)
#     Line #1073 (got 1 columns instead of 2)
#     Line #1074 (got 1 columns instead of 2)
#     Line #1075 (got 5 columns instead of 2)
#     Line #1076 (got 65 columns instead of 2)
#     Line #1077 (got 1 columns instead of 2)
#     Line #1078 (got 1 columns instead of 2)
#     Line #1079 (got 5 columns instead of 2)
#     Line #1080 (got 65 columns instead of 2)
#     Line #1081 (got 1 columns instead of 2)
#     Line #1082 (got 1 columns instead of 2)
#     Line #1083 (got 5 columns instead of 2)
#     Line #1084 (got 65 columns instead of 2)
#     Line #1085 (got 1 columns instead of 2)
#     Line #1086 (got 1 columns instead of 2)
#     Line #1087 (got 5 columns instead of 2)
#     Line #1088 (got 65 columns instead of 2)
#     Line #1089 (got 1 columns instead of 2)
#     Line #1090 (got 1 columns instead of 2)
#     Line #1091 (got 5 columns instead of 2)
#     Line #1092 (got 65 columns instead of 2)
#     Line #1093 (got 1 columns instead of 2)
#     Line #1094 (got 1 columns instead of 2)
#     Line #1095 (got 5 columns instead of 2)
#     Line #1096 (got 65 columns instead of 2)
#     Line #1097 (got 1 columns instead of 2)
#     Line #1098 (got 1 columns instead of 2)
#     Line #1099 (got 5 columns instead of 2)
#     Line #1100 (got 65 columns instead of 2)
#     Line #1101 (got 1 columns instead of 2)
#     Line #1102 (got 1 columns instead of 2)
#     Line #1103 (got 5 columns instead of 2)
#     Line #1104 (got 65 columns instead of 2)
#     Line #1105 (got 1 columns instead of 2)
#     Line #1106 (got 1 columns instead of 2)
#     Line #1107 (got 5 columns instead of 2)
#     Line #1108 (got 65 columns instead of 2)
#     Line #1109 (got 1 columns instead of 2)
#     Line #1110 (got 1 columns instead of 2)
#     Line #1111 (got 5 columns instead of 2)
#     Line #1112 (got 65 columns instead of 2)
#     Line #1113 (got 1 columns instead of 2)
#     Line #1114 (got 1 columns instead of 2)
#     Line #1115 (got 5 columns instead of 2)
#     Line #1116 (got 65 columns instead of 2)
#     Line #1117 (got 1 columns instead of 2)
#     Line #1118 (got 1 columns instead of 2)
#     Line #1119 (got 5 columns instead of 2)
#     Line #1120 (got 65 columns instead of 2)
#     Line #1121 (got 1 columns instead of 2)
#     Line #1122 (got 1 columns instead of 2)
#     Line #1123 (got 5 columns instead of 2)
#     Line #1124 (got 65 columns instead of 2)
#     Line #1125 (got 1 columns instead of 2)
#     Line #1126 (got 1 columns instead of 2)
#     Line #1127 (got 5 columns instead of 2)
#     Line #1128 (got 65 columns instead of 2)
#     Line #1129 (got 1 columns instead of 2)
#     Line #1130 (got 1 columns instead of 2)
#     Line #1131 (got 5 columns instead of 2)
#     Line #1132 (got 65 columns instead of 2)
#     Line #1133 (got 1 columns instead of 2)
#     Line #1134 (got 1 columns instead of 2)
#     Line #1135 (got 5 columns instead of 2)
#     Line #1136 (got 65 columns instead of 2)
#     Line #1137 (got 1 columns instead of 2)
#     Line #1138 (got 1 columns instead of 2)
#     Line #1139 (got 5 columns instead of 2)
#     Line #1140 (got 65 columns instead of 2)
#     Line #1141 (got 1 columns instead of 2)
#     Line #1142 (got 1 columns instead of 2)
#     Line #1143 (got 5 columns instead of 2)
#     Line #1144 (got 65 columns instead of 2)
#     Line #1145 (got 1 columns instead of 2)
#     Line #1146 (got 1 columns instead of 2)
#     Line #1147 (got 5 columns instead of 2)
#     Line #1148 (got 65 columns instead of 2)
#     Line #1149 (got 1 columns instead of 2)
#     Line #1150 (got 1 columns instead of 2)
#     Line #1151 (got 5 columns instead of 2)
#     Line #1152 (got 65 columns instead of 2)
#     Line #1153 (got 1 columns instead of 2)
#     Line #1154 (got 1 columns instead of 2)
#     Line #1155 (got 5 columns instead of 2)
#     Line #1156 (got 65 columns instead of 2)
#     Line #1157 (got 1 columns instead of 2)
#     Line #1158 (got 1 columns instead of 2)
#     Line #1159 (got 5 columns instead of 2)
#     Line #1160 (got 65 columns instead of 2)
#     Line #1161 (got 1 columns instead of 2)
#     Line #1162 (got 1 columns instead of 2)
#     Line #1163 (got 5 columns instead of 2)
#     Line #1164 (got 65 columns instead of 2)
#     Line #1165 (got 1 columns instead of 2)
#     Line #1166 (got 1 columns instead of 2)
#     Line #1167 (got 5 columns instead of 2)
#     Line #1168 (got 65 columns instead of 2)
#     Line #1169 (got 1 columns instead of 2)
#     Line #1170 (got 1 columns instead of 2)
#     Line #1171 (got 5 columns instead of 2)
#     Line #1172 (got 65 columns instead of 2)
#     Line #1173 (got 1 columns instead of 2)
#     Line #1174 (got 1 columns instead of 2)
#     Line #1175 (got 5 columns instead of 2)
#     Line #1176 (got 65 columns instead of 2)
#     Line #1177 (got 1 columns instead of 2)
#     Line #1178 (got 1 columns instead of 2)
#     Line #1179 (got 5 columns instead of 2)
#     Line #1180 (got 65 columns instead of 2)
#     Line #1181 (got 1 columns instead of 2)
#     Line #1182 (got 1 columns instead of 2)
#     Line #1183 (got 5 columns instead of 2)
#     Line #1184 (got 65 columns instead of 2)
#     Line #1185 (got 1 columns instead of 2)
#     Line #1186 (got 1 columns instead of 2)
#     Line #1187 (got 5 columns instead of 2)
#     Line #1188 (got 65 columns instead of 2)
#     Line #1189 (got 1 columns instead of 2)
#     Line #1190 (got 1 columns instead of 2)
#     Line #1191 (got 5 columns instead of 2)
#     Line #1192 (got 65 columns instead of 2)
#     Line #1193 (got 1 columns instead of 2)
#     Line #1194 (got 1 columns instead of 2)
#     Line #1195 (got 5 columns instead of 2)
#     Line #1196 (got 65 columns instead of 2)
#     Line #1197 (got 1 columns instead of 2)
#     Line #1198 (got 1 columns instead of 2)
#     Line #1199 (got 5 columns instead of 2)
#     Line #1200 (got 65 columns instead of 2)
#     Line #1201 (got 1 columns instead of 2)
#     Line #1202 (got 1 columns instead of 2)
#     Line #1203 (got 5 columns instead of 2)
#     Line #1204 (got 65 columns instead of 2)
#     Line #1205 (got 1 columns instead of 2)
#     Line #1206 (got 1 columns instead of 2)
#     Line #1207 (got 5 columns instead of 2)
#     Line #1208 (got 65 columns instead of 2)
#     Line #1209 (got 1 columns instead of 2)
#     Line #1210 (got 1 columns instead of 2)
#     Line #1211 (got 5 columns instead of 2)
#     Line #1212 (got 65 columns instead of 2)
#     Line #1213 (got 1 columns instead of 2)
#     Line #1214 (got 1 columns instead of 2)
#     Line #1215 (got 5 columns instead of 2)
#     Line #1216 (got 65 columns instead of 2)
#     Line #1217 (got 1 columns instead of 2)
#     Line #1218 (got 1 columns instead of 2)
#     Line #1219 (got 5 columns instead of 2)
#     Line #1220 (got 65 columns instead of 2)
#     Line #1221 (got 1 columns instead of 2)
#     Line #1222 (got 1 columns instead of 2)
#     Line #1223 (got 5 columns instead of 2)
#     Line #1224 (got 65 columns instead of 2)
#     Line #1225 (got 1 columns instead of 2)
#     Line #1226 (got 1 columns instead of 2)
#     Line #1227 (got 5 columns instead of 2)
#     Line #1228 (got 65 columns instead of 2)
#     Line #1229 (got 1 columns instead of 2)
#     Line #1230 (got 1 columns instead of 2)
#     Line #1231 (got 5 columns instead of 2)
#     Line #1232 (got 65 columns instead of 2)
#     Line #1233 (got 1 columns instead of 2)
#     Line #1234 (got 1 columns instead of 2)
#     Line #1235 (got 5 columns instead of 2)
#     Line #1236 (got 65 columns instead of 2)
#     Line #1237 (got 1 columns instead of 2)
#     Line #1238 (got 1 columns instead of 2)
#     Line #1239 (got 5 columns instead of 2)
#     Line #1240 (got 65 columns instead of 2)
#     Line #1241 (got 1 columns instead of 2)
#     Line #1242 (got 1 columns instead of 2)
#     Line #1243 (got 5 columns instead of 2)
#     Line #1244 (got 65 columns instead of 2)
#     Line #1245 (got 1 columns instead of 2)
#     Line #1246 (got 1 columns instead of 2)
#     Line #1247 (got 5 columns instead of 2)
#     Line #1248 (got 65 columns instead of 2)
#     Line #1249 (got 1 columns instead of 2)
#     Line #1250 (got 1 columns instead of 2)
#     Line #1251 (got 5 columns instead of 2)
#     Line #1252 (got 65 columns instead of 2)
#     Line #1253 (got 1 columns instead of 2)
#     Line #1254 (got 1 columns instead of 2)
#     Line #1255 (got 5 columns instead of 2)
#     Line #1256 (got 65 columns instead of 2)
#     Line #1257 (got 1 columns instead of 2)
#     Line #1258 (got 1 columns instead of 2)
#     Line #1259 (got 5 columns instead of 2)
#     Line #1260 (got 65 columns instead of 2)
#     Line #1261 (got 1 columns instead of 2)
#     Line #1262 (got 1 columns instead of 2)
#     Line #1263 (got 5 columns instead of 2)
#     Line #1264 (got 65 columns instead of 2)
#     Line #1265 (got 1 columns instead of 2)
#     Line #1266 (got 1 columns instead of 2)
#     Line #1267 (got 5 columns instead of 2)
#     Line #1268 (got 65 columns instead of 2)
#     Line #1269 (got 1 columns instead of 2)
#     Line #1270 (got 1 columns instead of 2)
#     Line #1271 (got 5 columns instead of 2)
#     Line #1272 (got 65 columns instead of 2)
#     Line #1273 (got 1 columns instead of 2)
#     Line #1274 (got 1 columns instead of 2)
#     Line #1275 (got 5 columns instead of 2)
#     Line #1276 (got 65 columns instead of 2)
#     Line #1277 (got 1 columns instead of 2)
#     Line #1278 (got 1 columns instead of 2)
#     Line #1279 (got 5 columns instead of 2)
#     Line #1280 (got 65 columns instead of 2)
#     Line #1281 (got 1 columns instead of 2)
#     Line #1282 (got 1 columns instead of 2)
#     Line #1283 (got 5 columns instead of 2)
#     Line #1284 (got 65 columns instead of 2)
#     Line #1285 (got 1 columns instead of 2)
#     Line #1286 (got 1 columns instead of 2)
#     Line #1287 (got 5 columns instead of 2)
#     Line #1288 (got 65 columns instead of 2)
#     Line #1289 (got 1 columns instead of 2)
#     Line #1290 (got 1 columns instead of 2)
#     Line #1291 (got 5 columns instead of 2)
#     Line #1292 (got 65 columns instead of 2)
#     Line #1293 (got 1 columns instead of 2)
#     Line #1294 (got 1 columns instead of 2)
#     Line #1295 (got 5 columns instead of 2)
#     Line #1296 (got 65 columns instead of 2)
#     Line #1297 (got 1 columns instead of 2)
#     Line #1298 (got 1 columns instead of 2)
#     Line #1299 (got 5 columns instead of 2)
#     Line #1300 (got 65 columns instead of 2)
#     Line #1301 (got 1 columns instead of 2)
#     Line #1302 (got 1 columns instead of 2)
#     Line #1303 (got 5 columns instead of 2)
# ...
#     Line #1553 (got 1 columns instead of 2)
#     Line #1554 (got 1 columns instead of 2)
#     Line #1555 (got 5 columns instead of 2)
#     Line #1556 (got 65 columns instead of 2)
#     Line #1557 (got 1 columns instead of 2)
#     Line #1558 (got 1 columns instead of 2)
#     Line #1559 (got 5 columns instead of 2)
#     Line #1560 (got 65 columns instead of 2)
#     Line #1561 (got 1 columns instead of 2)
#     Line #1562 (got 1 columns instead of 2)
#     Line #1563 (got 5 columns instead of 2)
#     Line #1564 (got 65 columns instead of 2)
#     Line #1565 (got 1 columns instead of 2)
#     Line #1566 (got 1 columns instead of 2)
#     Line #1567 (got 5 columns instead of 2)
#     Line #1568 (got 65 columns instead of 2)
#     Line #1569 (got 1 columns instead of 2)
#     Line #1570 (got 1 columns instead of 2)
#     Line #1571 (got 5 columns instead of 2)
#     Line #1572 (got 65 columns instead of 2)
#     Line #1573 (got 1 columns instead of 2)
#     Line #1574 (got 1 columns instead of 2)
#     Line #1575 (got 5 columns instead of 2)
#     Line #1576 (got 65 columns instead of 2)
#     Line #1577 (got 1 columns instead of 2)
#     Line #1578 (got 1 columns instead of 2)
#     Line #1579 (got 5 columns instead of 2)
#     Line #1580 (got 65 columns instead of 2)
#     Line #1581 (got 1 columns instead of 2)
#     Line #1582 (got 1 columns instead of 2)
#     Line #1583 (got 5 columns instead of 2)
#     Line #1584 (got 65 columns instead of 2)
#     Line #1585 (got 1 columns instead of 2)
#     Line #1586 (got 1 columns instead of 2)
#     Line #1587 (got 5 columns instead of 2)
#     Line #1588 (got 65 columns instead of 2)
#     Line #1589 (got 1 columns instead of 2)
#     Line #1590 (got 1 columns instead of 2)
#     Line #1591 (got 5 columns instead of 2)
#     Line #1592 (got 65 columns instead of 2)
#     Line #1593 (got 1 columns instead of 2)
#     Line #1594 (got 1 columns instead of 2)
#     Line #1595 (got 5 columns instead of 2)
#     Line #1596 (got 65 columns instead of 2)
#     Line #1597 (got 1 columns instead of 2)
#     Line #1598 (got 1 columns instead of 2)
#     Line #1599 (got 5 columns instead of 2)
#     Line #1600 (got 65 columns instead of 2)
#     Line #1601 (got 1 columns instead of 2)
#     Line #1602 (got 1 columns instead of 2)
#     Line #1603 (got 5 columns instead of 2)
#     Line #1604 (got 65 columns instead of 2)
#     Line #1605 (got 1 columns instead of 2)
#     Line #1606 (got 1 columns instead of 2)
#     Line #1607 (got 5 columns instead of 2)
#     Line #1608 (got 65 columns instead of 2)
#     Line #1609 (got 1 columns instead of 2)
#     Line #1610 (got 1 columns instead of 2)
#     Line #1611 (got 5 columns instead of 2)
#     Line #1612 (got 65 columns instead of 2)
#     Line #1613 (got 1 columns instead of 2)
#     Line #1614 (got 1 columns instead of 2)
#     Line #1615 (got 5 columns instead of 2)
#     Line #1616 (got 65 columns instead of 2)
#     Line #1617 (got 1 columns instead of 2)
#     Line #1618 (got 1 columns instead of 2)
#     Line #1619 (got 5 columns instead of 2)
#     Line #1620 (got 65 columns instead of 2)
#     Line #1621 (got 1 columns instead of 2)
#     Line #1622 (got 1 columns instead of 2)
#     Line #1623 (got 5 columns instead of 2)
#     Line #1624 (got 65 columns instead of 2)
#     Line #1625 (got 1 columns instead of 2)
#     Line #1626 (got 1 columns instead of 2)
#     Line #1627 (got 5 columns instead of 2)
#     Line #1628 (got 65 columns instead of 2)
#     Line #1629 (got 1 columns instead of 2)
#     Line #1630 (got 1 columns instead of 2)
#     Line #1631 (got 5 columns instead of 2)
#     Line #1632 (got 65 columns instead of 2)
#     Line #1633 (got 1 columns instead of 2)
#     Line #1634 (got 1 columns instead of 2)
#     Line #1635 (got 5 columns instead of 2)
#     Line #1636 (got 65 columns instead of 2)
#     Line #1637 (got 1 columns instead of 2)
#     Line #1638 (got 1 columns instead of 2)
#     Line #1639 (got 5 columns instead of 2)
#     Line #1640 (got 65 columns instead of 2)
#     Line #1641 (got 1 columns instead of 2)
#     Line #1642 (got 1 columns instead of 2)
#     Line #1643 (got 5 columns instead of 2)
#     Line #1644 (got 65 columns instead of 2)
#     Line #1645 (got 1 columns instead of 2)
#     Line #1646 (got 1 columns instead of 2)
#     Line #1647 (got 5 columns instead of 2)
#     Line #1648 (got 65 columns instead of 2)
#     Line #1649 (got 1 columns instead of 2)
#     Line #1650 (got 1 columns instead of 2)
#     Line #1651 (got 5 columns instead of 2)
#     Line #1652 (got 65 columns instead of 2)
#     Line #1653 (got 1 columns instead of 2)
#     Line #1654 (got 1 columns instead of 2)
#     Line #1655 (got 5 columns instead of 2)
#     Line #1656 (got 65 columns instead of 2)
#     Line #1657 (got 1 columns instead of 2)
#     Line #1658 (got 1 columns instead of 2)
#     Line #1659 (got 5 columns instead of 2)
#     Line #1660 (got 65 columns instead of 2)
#     Line #1661 (got 1 columns instead of 2)
#     Line #1662 (got 1 columns instead of 2)
#     Line #1663 (got 5 columns instead of 2)
#     Line #1664 (got 65 columns instead of 2)
#     Line #1665 (got 1 columns instead of 2)
#     Line #1666 (got 1 columns instead of 2)
#     Line #1667 (got 5 columns instead of 2)
#     Line #1668 (got 65 columns instead of 2)
#     Line #1669 (got 1 columns instead of 2)
#     Line #1670 (got 1 columns instead of 2)
#     Line #1671 (got 5 columns instead of 2)
#     Line #1672 (got 65 columns instead of 2)
#     Line #1673 (got 1 columns instead of 2)
#     Line #1674 (got 1 columns instead of 2)
#     Line #1675 (got 5 columns instead of 2)
#     Line #1676 (got 65 columns instead of 2)
#     Line #1677 (got 1 columns instead of 2)
#     Line #1678 (got 1 columns instead of 2)
#     Line #1679 (got 5 columns instead of 2)
#     Line #1680 (got 65 columns instead of 2)
#     Line #1681 (got 1 columns instead of 2)
#     Line #1682 (got 1 columns instead of 2)
#     Line #1683 (got 5 columns instead of 2)
#     Line #1684 (got 65 columns instead of 2)
#     Line #1685 (got 1 columns instead of 2)
#     Line #1686 (got 1 columns instead of 2)
#     Line #1687 (got 5 columns instead of 2)
#     Line #1688 (got 65 columns instead of 2)
#     Line #1689 (got 1 columns instead of 2)
#     Line #1690 (got 1 columns instead of 2)
#     Line #1691 (got 5 columns instead of 2)
#     Line #1692 (got 65 columns instead of 2)
#     Line #1693 (got 1 columns instead of 2)
#     Line #1694 (got 1 columns instead of 2)
#     Line #1695 (got 5 columns instead of 2)
#     Line #1696 (got 65 columns instead of 2)
#     Line #1697 (got 1 columns instead of 2)
#     Line #1698 (got 1 columns instead of 2)
#     Line #1699 (got 5 columns instead of 2)
#     Line #1700 (got 65 columns instead of 2)
#     Line #1701 (got 1 columns instead of 2)
#     Line #1702 (got 1 columns instead of 2)
#     Line #1703 (got 5 columns instead of 2)
#     Line #1704 (got 65 columns instead of 2)
#     Line #1705 (got 1 columns instead of 2)
#     Line #1706 (got 1 columns instead of 2)
#     Line #1707 (got 5 columns instead of 2)
#     Line #1708 (got 65 columns instead of 2)
#     Line #1709 (got 1 columns instead of 2)
#     Line #1710 (got 1 columns instead of 2)
#     Line #1711 (got 5 columns instead of 2)
#     Line #1712 (got 65 columns instead of 2)
#     Line #1713 (got 1 columns instead of 2)
#     Line #1714 (got 1 columns instead of 2)
#     Line #1715 (got 5 columns instead of 2)
#     Line #1716 (got 65 columns instead of 2)
#     Line #1717 (got 1 columns instead of 2)
#     Line #1718 (got 1 columns instead of 2)
#     Line #1719 (got 5 columns instead of 2)
#     Line #1720 (got 65 columns instead of 2)
#     Line #1721 (got 1 columns instead of 2)
#     Line #1722 (got 1 columns instead of 2)
#     Line #1723 (got 5 columns instead of 2)
#     Line #1724 (got 65 columns instead of 2)
#     Line #1725 (got 1 columns instead of 2)
#     Line #1726 (got 1 columns instead of 2)
#     Line #1727 (got 5 columns instead of 2)
#     Line #1728 (got 65 columns instead of 2)
#     Line #1729 (got 1 columns instead of 2)
#     Line #1730 (got 1 columns instead of 2)
#     Line #1731 (got 5 columns instead of 2)
#     Line #1732 (got 65 columns instead of 2)
#     Line #1733 (got 1 columns instead of 2)
#     Line #1734 (got 1 columns instead of 2)
#     Line #1735 (got 5 columns instead of 2)
#     Line #1736 (got 65 columns instead of 2)
#     Line #1737 (got 1 columns instead of 2)
#     Line #1738 (got 1 columns instead of 2)
#     Line #1739 (got 5 columns instead of 2)
#     Line #1740 (got 65 columns instead of 2)
#     Line #1741 (got 1 columns instead of 2)
#     Line #1742 (got 1 columns instead of 2)
#     Line #1743 (got 5 columns instead of 2)
#     Line #1744 (got 65 columns instead of 2)
#     Line #1745 (got 1 columns instead of 2)
#     Line #1746 (got 1 columns instead of 2)
#     Line #1747 (got 5 columns instead of 2)
#     Line #1748 (got 65 columns instead of 2)
#     Line #1749 (got 1 columns instead of 2)
#     Line #1750 (got 1 columns instead of 2)
#     Line #1751 (got 5 columns instead of 2)
#     Line #1752 (got 65 columns instead of 2)
#     Line #1753 (got 1 columns instead of 2)
#     Line #1754 (got 1 columns instead of 2)
#     Line #1755 (got 5 columns instead of 2)
#     Line #1756 (got 65 columns instead of 2)
#     Line #1757 (got 1 columns instead of 2)
#     Line #1758 (got 1 columns instead of 2)
#     Line #1759 (got 5 columns instead of 2)
#     Line #1760 (got 65 columns instead of 2)
#     Line #1761 (got 1 columns instead of 2)
#     Line #1762 (got 1 columns instead of 2)
#     Line #1763 (got 5 columns instead of 2)
#     Line #1764 (got 65 columns instead of 2)
#     Line #1765 (got 1 columns instead of 2)
#     Line #1766 (got 1 columns instead of 2)
#     Line #1767 (got 5 columns instead of 2)
#     Line #1768 (got 65 columns instead of 2)
#     Line #1769 (got 1 columns instead of 2)
#     Line #1770 (got 1 columns instead of 2)
#     Line #1771 (got 5 columns instead of 2)
#     Line #1772 (got 65 columns instead of 2)
#     Line #1773 (got 1 columns instead of 2)
#     Line #1774 (got 1 columns instead of 2)
#     Line #1775 (got 5 columns instead of 2)
#     Line #1776 (got 65 columns instead of 2)
#     Line #1777 (got 1 columns instead of 2)
#     Line #1778 (got 1 columns instead of 2)
#     Line #1779 (got 5 columns instead of 2)
#     Line #1780 (got 65 columns instead of 2)
#     Line #1781 (got 1 columns instead of 2)
#     Line #1782 (got 1 columns instead of 2)
#     Line #1783 (got 5 columns instead of 2)
#     Line #1784 (got 65 columns instead of 2)
#     Line #1785 (got 1 columns instead of 2)
#     Line #1786 (got 1 columns instead of 2)
#     Line #1787 (got 5 columns instead of 2)
#     Line #1788 (got 65 columns instead of 2)
#     Line #1789 (got 1 columns instead of 2)
#     Line #1790 (got 1 columns instead of 2)
#     Line #1791 (got 5 columns instead of 2)
#     Line #1792 (got 65 columns instead of 2)
#     Line #1793 (got 1 columns instead of 2)
#     Line #1794 (got 1 columns instead of 2)
#     Line #1795 (got 5 columns instead of 2)
#     Line #1796 (got 65 columns instead of 2)
#     Line #1797 (got 1 columns instead of 2)
#     Line #1798 (got 1 columns instead of 2)
#     Line #1799 (got 5 columns instead of 2)
#     Line #1800 (got 65 columns instead of 2)
#     Line #1801 (got 1 columns instead of 2)
#     Line #1802 (got 1 columns instead of 2)
#     Line #1803 (got 5 columns instead of 2)
#     Line #1804 (got 65 columns instead of 2)
#     Line #1805 (got 1 columns instead of 2)
#     Line #1806 (got 1 columns instead of 2)
#     Line #1807 (got 5 columns instead of 2)
#     Line #1808 (got 65 columns instead of 2)
#     Line #1809 (got 1 columns instead of 2)
#     Line #1810 (got 1 columns instead of 2)
#     Line #1811 (got 5 columns instead of 2)
#     Line #1812 (got 65 columns instead of 2)
#     Line #1813 (got 1 columns instead of 2)
#     Line #1814 (got 1 columns instead of 2)
#     Line #1815 (got 5 columns instead of 2)
#     Line #1816 (got 65 columns instead of 2)
#     Line #1817 (got 1 columns instead of 2)
#     Line #1818 (got 1 columns instead of 2)
#     Line #1819 (got 5 columns instead of 2)
#     Line #1820 (got 65 columns instead of 2)
#     Line #1821 (got 1 columns instead of 2)
#     Line #1822 (got 1 columns instead of 2)
#     Line #1823 (got 5 columns instead of 2)
#     Line #1824 (got 65 columns instead of 2)
#     Line #1825 (got 1 columns instead of 2)
#     Line #1826 (got 1 columns instead of 2)
#     Line #1828 (got 9 columns instead of 2)
#     Line #1829 (got 13 columns instead of 2)
#     Line #1830 (got 52 columns instead of 2)
#     Line #1831 (got 1 columns instead of 2)
#     Line #1832 (got 1 columns instead of 2)
#     Line #1833 (got 6 columns instead of 2)
#     Line #1834 (got 8 columns instead of 2)
#     Line #1835 (got 8 columns instead of 2)
#     Line #1836 (got 8 columns instead of 2)
#     Line #1837 (got 8 columns instead of 2)
#     Line #1838 (got 1 columns instead of 2)
#     Line #1839 (got 1 columns instead of 2)
#     Line #1840 (got 1 columns instead of 2)
#     Line #1842 (got 1 columns instead of 2)
#     Line #1844 (got 1 columns instead of 2)
#     Line #1848 (got 4 columns instead of 2)
#     Line #1849 (got 5 columns instead of 2)
#     Line #1850 (got 11 columns instead of 2)
#     Line #1851 (got 14 columns instead of 2)
#     Line #1852 (got 14 columns instead of 2)
#     Line #1853 (got 4 columns instead of 2)
#     Line #1855 (got 1 columns instead of 2)
#     Line #1859 (got 1 columns instead of 2)
#     Line #1860 (got 3 columns instead of 2)
#     Line #1861 (got 1 columns instead of 2)
#     Line #1863 (got 1 columns instead of 2)
#     Line #1864 (got 1 columns instead of 2)
#     Line #1867 (got 1 columns instead of 2)
#     Line #1870 (got 6 columns instead of 2)
#     Line #1871 (got 12 columns instead of 2)
#     Line #1872 (got 5 columns instead of 2)
#     Line #1873 (got 8 columns instead of 2)
#     Line #1874 (got 8 columns instead of 2)
#     Line #1875 (got 8 columns instead of 2)
#     Line #1876 (got 8 columns instead of 2)
#     Line #1877 (got 8 columns instead of 2)
#     Line #1878 (got 7 columns instead of 2)
#     Line #1879 (got 1 columns instead of 2)
#     Line #1881 (got 6 columns instead of 2)
#     Line #1882 (got 66 columns instead of 2)
#     Line #1883 (got 1 columns instead of 2)
#     Line #1884 (got 5 columns instead of 2)
#     Line #1885 (got 9 columns instead of 2)
#     Line #1886 (got 8 columns instead of 2)
#     Line #1887 (got 8 columns instead of 2)
#     Line #1888 (got 8 columns instead of 2)
#     Line #1889 (got 8 columns instead of 2)
#     Line #1890 (got 7 columns instead of 2)
#     Line #1892 (got 1 columns instead of 2)
#     Line #1893 (got 1 columns instead of 2)
#     Line #1894 (got 4 columns instead of 2)
#     Line #1895 (got 3 columns instead of 2)
#     Line #1896 (got 1 columns instead of 2)
#     Line #1897 (got 1 columns instead of 2)
#     Line #1901 (got 5 columns instead of 2)
#     Line #1902 (got 29 columns instead of 2)
#     Line #1903 (got 6 columns instead of 2)
#     Line #1904 (got 25 columns instead of 2)
#     Line #1905 (got 1 columns instead of 2)
#     Line #1906 (got 8 columns instead of 2)
#     Line #1907 (got 1 columns instead of 2)
#     Line #1910 (got 5 columns instead of 2)
#     Line #1911 (got 5 columns instead of 2)
#     Line #1913 (got 6 columns instead of 2)
#     Line #1917 (got 7 columns instead of 2)
#     Line #1918 (got 1 columns instead of 2)
#     Line #1919 (got 29 columns instead of 2)
#     Line #1920 (got 15 columns instead of 2)
#     Line #1921 (got 15 columns instead of 2)
#     Line #1922 (got 1 columns instead of 2)
#     Line #1924 (got 7 columns instead of 2)
#     Line #1925 (got 4 columns instead of 2)
#     Line #1926 (got 7 columns instead of 2)
#     Line #1927 (got 11 columns instead of 2)
#     Line #1928 (got 25 columns instead of 2)
#     Line #1929 (got 1 columns instead of 2)
#     Line #1930 (got 4 columns instead of 2)
#     Line #1931 (got 1 columns instead of 2)
#     Line #1932 (got 1 columns instead of 2)
#     Line #1933 (got 1 columns instead of 2)
#     Line #1935 (got 9 columns instead of 2)
#     Line #1936 (got 7 columns instead of 2)
#     Line #1937 (got 1 columns instead of 2)
#     Line #1938 (got 1 columns instead of 2)
#     Line #1940 (got 4 columns instead of 2)
#     Line #1942 (got 1 columns instead of 2)
#     Line #1943 (got 1 columns instead of 2)

# %% [markdown]
# The same idea can also be applied to k-means clustering.  In this algorithm, the number of clusters is set _apriori_ and similar time series are clustered together.

# %%
import random

def k_means_clust(data,num_clust,num_iter,w=5):
    centroids=random.sample(data,num_clust)
    counter=0
    for n in range(num_iter):
        counter+=1
        print counter
        assignments={}
        #assign data points to clusters
        for ind,i in enumerate(data):
            min_dist=float('inf')
            closest_clust=None
            for c_ind,j in enumerate(centroids):
                if LB_Keogh(i,j,5)<min_dist:
                    cur_dist=DTWDistance(i,j,w)
                    if cur_dist<min_dist:
                        min_dist=cur_dist
                        closest_clust=c_ind
            if closest_clust in assignments:
                assignments[closest_clust].append(ind)
            else:
                assignments[closest_clust]=[]
    
        #recalculate centroids of clusters
        for key in assignments:
            clust_sum=0
            for k in assignments[key]:
                clust_sum=clust_sum+data[k]
            centroids[key]=[m/len(assignments[key]) for m in clust_sum]
    
    return centroids

# %%
# !ls
# Out:
# sample_data  test.csv  train.csv

# %% [markdown]
# Let's test it on the entire data set (i.e. the training set and the test set stacked together).

# %%
train = np.genfromtxt('train.csv', delimiter='\t')
test = np.genfromtxt('test.csv', delimiter='\t')
data=np.vstack((train[:,:-1],test[:,:-1]))

import matplotlib.pylab as plt

centroids=k_means_clust(data,4,10,4)
for i in centroids:
    
    plt.plot(i)

plt.show()
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-26-4465615ee3ac> in <module>()
# ----> 1 train = np.genfromtxt('train.csv', delimiter='\t')
#       2 test = np.genfromtxt('test.csv', delimiter='\t')
#       3 data=np.vstack((train[:,:-1],test[:,:-1]))
#       4
#       5 import matplotlib.pylab as plt
#
# /usr/local/lib/python2.7/dist-packages/numpy/lib/npyio.pyc in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding)
#    2017             # Raise an exception ?
#    2018             if invalid_raise:
# -> 2019                 raise ValueError(errmsg)
#    2020             # Issue a warning ?
#    2021             else:
#
# ValueError: Some errors were detected !
#     Line #628 (got 61 columns instead of 1)
#     Line #632 (got 61 columns instead of 1)
#     Line #636 (got 61 columns instead of 1)
#     Line #640 (got 61 columns instead of 1)
#     Line #644 (got 61 columns instead of 1)
#     Line #648 (got 61 columns instead of 1)
#     Line #652 (got 61 columns instead of 1)
#     Line #656 (got 61 columns instead of 1)
#     Line #660 (got 61 columns instead of 1)
#     Line #664 (got 61 columns instead of 1)
#     Line #668 (got 61 columns instead of 1)
#     Line #672 (got 61 columns instead of 1)
#     Line #676 (got 61 columns instead of 1)
#     Line #680 (got 61 columns instead of 1)
#     Line #684 (got 61 columns instead of 1)
#     Line #688 (got 61 columns instead of 1)
#     Line #692 (got 61 columns instead of 1)
#     Line #696 (got 61 columns instead of 1)
#     Line #700 (got 61 columns instead of 1)
#     Line #704 (got 61 columns instead of 1)
#     Line #708 (got 61 columns instead of 1)
#     Line #712 (got 61 columns instead of 1)
#     Line #716 (got 61 columns instead of 1)
#     Line #720 (got 61 columns instead of 1)
#     Line #724 (got 61 columns instead of 1)
#     Line #728 (got 61 columns instead of 1)
#     Line #732 (got 61 columns instead of 1)
#     Line #736 (got 61 columns instead of 1)
#     Line #740 (got 61 columns instead of 1)
#     Line #744 (got 61 columns instead of 1)
#     Line #748 (got 61 columns instead of 1)
#     Line #752 (got 61 columns instead of 1)
#     Line #756 (got 61 columns instead of 1)
#     Line #760 (got 61 columns instead of 1)
#     Line #764 (got 61 columns instead of 1)
#     Line #768 (got 61 columns instead of 1)
#     Line #772 (got 61 columns instead of 1)
#     Line #776 (got 61 columns instead of 1)
#     Line #780 (got 61 columns instead of 1)
#     Line #784 (got 61 columns instead of 1)
#     Line #788 (got 61 columns instead of 1)
#     Line #792 (got 61 columns instead of 1)
#     Line #796 (got 61 columns instead of 1)
#     Line #800 (got 61 columns instead of 1)
#     Line #804 (got 61 columns instead of 1)
#     Line #808 (got 61 columns instead of 1)
#     Line #812 (got 61 columns instead of 1)
#     Line #816 (got 61 columns instead of 1)
#     Line #820 (got 61 columns instead of 1)
#     Line #824 (got 61 columns instead of 1)
#     Line #828 (got 61 columns instead of 1)
#     Line #832 (got 61 columns instead of 1)
#     Line #836 (got 61 columns instead of 1)
#     Line #840 (got 61 columns instead of 1)
#     Line #844 (got 61 columns instead of 1)
#     Line #848 (got 61 columns instead of 1)
#     Line #852 (got 61 columns instead of 1)
#     Line #856 (got 61 columns instead of 1)
#     Line #860 (got 61 columns instead of 1)
#     Line #864 (got 61 columns instead of 1)
#     Line #868 (got 61 columns instead of 1)
#     Line #872 (got 61 columns instead of 1)
#     Line #876 (got 61 columns instead of 1)
#     Line #880 (got 61 columns instead of 1)
#     Line #884 (got 61 columns instead of 1)
#     Line #888 (got 61 columns instead of 1)
#     Line #892 (got 61 columns instead of 1)
#     Line #896 (got 61 columns instead of 1)
#     Line #900 (got 61 columns instead of 1)
#     Line #904 (got 61 columns instead of 1)
#     Line #908 (got 61 columns instead of 1)
#     Line #912 (got 61 columns instead of 1)
#     Line #916 (got 61 columns instead of 1)
#     Line #920 (got 61 columns instead of 1)
#     Line #924 (got 61 columns instead of 1)
#     Line #928 (got 61 columns instead of 1)
#     Line #932 (got 61 columns instead of 1)
#     Line #936 (got 61 columns instead of 1)
#     Line #940 (got 61 columns instead of 1)
#     Line #944 (got 61 columns instead of 1)
#     Line #948 (got 61 columns instead of 1)
#     Line #952 (got 61 columns instead of 1)
#     Line #956 (got 61 columns instead of 1)
#     Line #960 (got 61 columns instead of 1)
#     Line #964 (got 61 columns instead of 1)
#     Line #968 (got 61 columns instead of 1)
#     Line #972 (got 61 columns instead of 1)
#     Line #976 (got 61 columns instead of 1)
#     Line #980 (got 61 columns instead of 1)
#     Line #984 (got 61 columns instead of 1)
#     Line #988 (got 61 columns instead of 1)
#     Line #992 (got 61 columns instead of 1)
#     Line #996 (got 61 columns instead of 1)
#     Line #1000 (got 61 columns instead of 1)
#     Line #1004 (got 61 columns instead of 1)
#     Line #1008 (got 61 columns instead of 1)
#     Line #1012 (got 61 columns instead of 1)
#     Line #1016 (got 61 columns instead of 1)
#     Line #1020 (got 61 columns instead of 1)
#     Line #1024 (got 61 columns instead of 1)
#     Line #1028 (got 61 columns instead of 1)
#     Line #1032 (got 61 columns instead of 1)
#     Line #1036 (got 61 columns instead of 1)
#     Line #1040 (got 61 columns instead of 1)
#     Line #1044 (got 61 columns instead of 1)
#     Line #1048 (got 61 columns instead of 1)
#     Line #1052 (got 61 columns instead of 1)
#     Line #1056 (got 61 columns instead of 1)
#     Line #1060 (got 61 columns instead of 1)
#     Line #1064 (got 61 columns instead of 1)
#     Line #1068 (got 61 columns instead of 1)
#     Line #1072 (got 61 columns instead of 1)
#     Line #1076 (got 61 columns instead of 1)
#     Line #1080 (got 61 columns instead of 1)
#     Line #1084 (got 61 columns instead of 1)
#     Line #1088 (got 61 columns instead of 1)
#     Line #1092 (got 61 columns instead of 1)
#     Line #1096 (got 61 columns instead of 1)
#     Line #1100 (got 61 columns instead of 1)
#     Line #1104 (got 61 columns instead of 1)
#     Line #1108 (got 61 columns instead of 1)
#     Line #1112 (got 61 columns instead of 1)
#     Line #1116 (got 61 columns instead of 1)
#     Line #1120 (got 61 columns instead of 1)
#     Line #1124 (got 61 columns instead of 1)
#     Line #1128 (got 61 columns instead of 1)
#     Line #1132 (got 61 columns instead of 1)
#     Line #1136 (got 61 columns instead of 1)
#     Line #1140 (got 61 columns instead of 1)
#     Line #1144 (got 61 columns instead of 1)
#     Line #1148 (got 61 columns instead of 1)
#     Line #1152 (got 61 columns instead of 1)
#     Line #1156 (got 61 columns instead of 1)
#     Line #1160 (got 61 columns instead of 1)
#     Line #1164 (got 61 columns instead of 1)
#     Line #1168 (got 61 columns instead of 1)
#     Line #1172 (got 61 columns instead of 1)
#     Line #1176 (got 61 columns instead of 1)
#     Line #1180 (got 61 columns instead of 1)
#     Line #1184 (got 61 columns instead of 1)
#     Line #1188 (got 61 columns instead of 1)
#     Line #1192 (got 61 columns instead of 1)
#     Line #1196 (got 61 columns instead of 1)
#     Line #1200 (got 61 columns instead of 1)
#     Line #1204 (got 61 columns instead of 1)
#     Line #1208 (got 61 columns instead of 1)
#     Line #1212 (got 61 columns instead of 1)
#     Line #1216 (got 61 columns instead of 1)
#     Line #1220 (got 61 columns instead of 1)
#     Line #1224 (got 61 columns instead of 1)
#     Line #1228 (got 61 columns instead of 1)
#     Line #1232 (got 61 columns instead of 1)
#     Line #1236 (got 61 columns instead of 1)
#     Line #1240 (got 61 columns instead of 1)
#     Line #1244 (got 61 columns instead of 1)
#     Line #1248 (got 61 columns instead of 1)
#     Line #1252 (got 61 columns instead of 1)
#     Line #1256 (got 61 columns instead of 1)
#     Line #1260 (got 61 columns instead of 1)
#     Line #1264 (got 61 columns instead of 1)
#     Line #1268 (got 61 columns instead of 1)
#     Line #1272 (got 61 columns instead of 1)
#     Line #1276 (got 61 columns instead of 1)
#     Line #1280 (got 61 columns instead of 1)
#     Line #1284 (got 61 columns instead of 1)
#     Line #1288 (got 61 columns instead of 1)
#     Line #1292 (got 61 columns instead of 1)
#     Line #1296 (got 61 columns instead of 1)
#     Line #1300 (got 61 columns instead of 1)
#     Line #1304 (got 61 columns instead of 1)
#     Line #1308 (got 61 columns instead of 1)
#     Line #1312 (got 61 columns instead of 1)
#     Line #1316 (got 61 columns instead of 1)
#     Line #1320 (got 61 columns instead of 1)
#     Line #1324 (got 61 columns instead of 1)
#     Line #1328 (got 61 columns instead of 1)
#     Line #1332 (got 61 columns instead of 1)
#     Line #1336 (got 61 columns instead of 1)
#     Line #1340 (got 61 columns instead of 1)
#     Line #1344 (got 61 columns instead of 1)
#     Line #1348 (got 61 columns instead of 1)
#     Line #1352 (got 61 columns instead of 1)
#     Line #1356 (got 61 columns instead of 1)
#     Line #1360 (got 61 columns instead of 1)
#     Line #1364 (got 61 columns instead of 1)
#     Line #1368 (got 61 columns instead of 1)
#     Line #1372 (got 61 columns instead of 1)
#     Line #1376 (got 61 columns instead of 1)
#     Line #1380 (got 61 columns instead of 1)
#     Line #1384 (got 61 columns instead of 1)
#     Line #1388 (got 61 columns instead of 1)
#     Line #1392 (got 61 columns instead of 1)
#     Line #1396 (got 61 columns instead of 1)
#     Line #1400 (got 61 columns instead of 1)
#     Line #1404 (got 61 columns instead of 1)
#     Line #1408 (got 61 columns instead of 1)
#     Line #1412 (got 61 columns instead of 1)
#     Line #1416 (got 61 columns instead of 1)
#     Line #1420 (got 61 columns instead of 1)
#     Line #1424 (got 61 columns instead of 1)
#     Line #1428 (got 61 columns instead of 1)
#     Line #1432 (got 61 columns instead of 1)
#     Line #1436 (got 61 columns instead of 1)
#     Line #1440 (got 61 columns instead of 1)
#     Line #1444 (got 61 columns instead of 1)
#     Line #1448 (got 61 columns instead of 1)
#     Line #1452 (got 61 columns instead of 1)
#     Line #1456 (got 61 columns instead of 1)
#     Line #1460 (got 61 columns instead of 1)
#     Line #1464 (got 61 columns instead of 1)
#     Line #1468 (got 61 columns instead of 1)
#     Line #1472 (got 61 columns instead of 1)
#     Line #1476 (got 61 columns instead of 1)
#     Line #1480 (got 61 columns instead of 1)
#     Line #1484 (got 61 columns instead of 1)
#     Line #1488 (got 61 columns instead of 1)
#     Line #1492 (got 61 columns instead of 1)
#     Line #1496 (got 61 columns instead of 1)
#     Line #1500 (got 61 columns instead of 1)
#     Line #1504 (got 61 columns instead of 1)
#     Line #1508 (got 61 columns instead of 1)
#     Line #1512 (got 61 columns instead of 1)
#     Line #1516 (got 61 columns instead of 1)
#     Line #1520 (got 61 columns instead of 1)
#     Line #1524 (got 61 columns instead of 1)
#     Line #1528 (got 61 columns instead of 1)
#     Line #1532 (got 61 columns instead of 1)
#     Line #1536 (got 61 columns instead of 1)
#     Line #1540 (got 61 columns instead of 1)
#     Line #1544 (got 61 columns instead of 1)
#     Line #1548 (got 61 columns instead of 1)
#     Line #1552 (got 61 columns instead of 1)
#     Line #1556 (got 61 columns instead of 1)
#     Line #1560 (got 61 columns instead of 1)
#     Line #1564 (got 61 columns instead of 1)
#     Line #1568 (got 61 columns instead of 1)
#     Line #1572 (got 61 columns instead of 1)
#     Line #1576 (got 61 columns instead of 1)
#     Line #1580 (got 61 columns instead of 1)
#     Line #1584 (got 61 columns instead of 1)
#     Line #1588 (got 61 columns instead of 1)
#     Line #1592 (got 61 columns instead of 1)
#     Line #1596 (got 61 columns instead of 1)
#     Line #1600 (got 61 columns instead of 1)
#     Line #1604 (got 61 columns instead of 1)
#     Line #1608 (got 61 columns instead of 1)
#     Line #1612 (got 61 columns instead of 1)
#     Line #1616 (got 61 columns instead of 1)
#     Line #1620 (got 61 columns instead of 1)
#     Line #1624 (got 61 columns instead of 1)
#     Line #1628 (got 61 columns instead of 1)
#     Line #1632 (got 61 columns instead of 1)
#     Line #1636 (got 61 columns instead of 1)
#     Line #1640 (got 61 columns instead of 1)
#     Line #1644 (got 61 columns instead of 1)
#     Line #1648 (got 61 columns instead of 1)
#     Line #1652 (got 61 columns instead of 1)
#     Line #1656 (got 61 columns instead of 1)
#     Line #1660 (got 61 columns instead of 1)
#     Line #1664 (got 61 columns instead of 1)
#     Line #1668 (got 61 columns instead of 1)
#     Line #1672 (got 61 columns instead of 1)
#     Line #1676 (got 61 columns instead of 1)
#     Line #1680 (got 61 columns instead of 1)
#     Line #1684 (got 61 columns instead of 1)
#     Line #1688 (got 61 columns instead of 1)
#     Line #1692 (got 61 columns instead of 1)
#     Line #1696 (got 61 columns instead of 1)
#     Line #1700 (got 61 columns instead of 1)
#     Line #1704 (got 61 columns instead of 1)
#     Line #1708 (got 61 columns instead of 1)
#     Line #1712 (got 61 columns instead of 1)
#     Line #1716 (got 61 columns instead of 1)
#     Line #1720 (got 61 columns instead of 1)
#     Line #1724 (got 61 columns instead of 1)
#     Line #1728 (got 61 columns instead of 1)
#     Line #1732 (got 61 columns instead of 1)
#     Line #1736 (got 61 columns instead of 1)
#     Line #1740 (got 61 columns instead of 1)
#     Line #1744 (got 61 columns instead of 1)
#     Line #1748 (got 61 columns instead of 1)
#     Line #1752 (got 61 columns instead of 1)
#     Line #1756 (got 61 columns instead of 1)
#     Line #1760 (got 61 columns instead of 1)
#     Line #1764 (got 61 columns instead of 1)
#     Line #1768 (got 61 columns instead of 1)
#     Line #1772 (got 61 columns instead of 1)
#     Line #1776 (got 61 columns instead of 1)
#     Line #1780 (got 61 columns instead of 1)
#     Line #1784 (got 61 columns instead of 1)
#     Line #1788 (got 61 columns instead of 1)
#     Line #1792 (got 61 columns instead of 1)
#     Line #1796 (got 61 columns instead of 1)
#     Line #1800 (got 61 columns instead of 1)
#     Line #1804 (got 61 columns instead of 1)
#     Line #1808 (got 61 columns instead of 1)
#     Line #1812 (got 61 columns instead of 1)
#     Line #1816 (got 61 columns instead of 1)
#     Line #1820 (got 61 columns instead of 1)
#     Line #1824 (got 61 columns instead of 1)
